# %% [markdown]
# <a href="https://colab.research.google.com/github/harshatha-21/harshathaeng/blob/main/wikipedia_bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
{
  "cells": [
    {
      "cell_type": "markdown",
      "metadata": {
        "id": "view-in-github",
        "colab_type": "text"
      },
      "source": [
        "<a href=\"https://colab.research.google.com/github/Kalyanianikkath/NM-Genrative-AI/blob/main/wikipedia_bot.ipynb\" target=\"_parent\"><img src=\"https://colab.research.google.com/assets/colab-badge.svg\" alt=\"Open In Colab\"/></a>"
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 729
        },
        "id": "Iazbf7sElSKF",
        "outputId": "3d5032de-fd21-4041-bd50-3df87c7cd74d"
      },
      "outputs": [
        {
          "name": "stdout",
          "output_type": "stream",
          "text": [
            "  Preparing metadata (setup.py) ... \u001b[?25l\u001b[?25hdone\n",
            "\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m30.7/30.7 MB\u001b[0m \u001b[31m29.5 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
            "\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m46.5/46.5 MB\u001b[0m \u001b[31m11.4 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
            "\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m322.2/322.2 kB\u001b[0m \u001b[31m14.2 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
            "\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m95.2/95.2 kB\u001b[0m \u001b[31m6.5 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
            "\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m11.3/11.3 MB\u001b[0m \u001b[31m42.0 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
            "\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m72.0/72.0 kB\u001b[0m \u001b[31m4.3 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
            "\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m62.3/62.3 kB\u001b[0m \u001b[31m3.2 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
            "\u001b[?25h  Building wheel for wikipedia (setup.py) ... \u001b[?25l\u001b[?25hdone\n"
          ]
        },
        {
          "ename": "MessageError",
          "evalue": "Error: credential propagation was unsuccessful",
          "output_type": "error",
          "traceback": [
            "\u001b[0;31m---------------------------------------------------------------------------\u001b[0m",
            "\u001b[0;31mMessageError\u001b[0m                              Traceback (most recent call last)",
            "\u001b[0;32m<ipython-input-1-6fd4f08e5a38>\u001b[0m in \u001b[0;36m<cell line: 0>\u001b[0;34m()\u001b[0m\n\u001b[1;32m      4\u001b[0m \u001b[0;31m# Authenticate and import\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[1;32m      5\u001b[0m \u001b[0;32mfrom\u001b[0m \u001b[0mgoogle\u001b[0m\u001b[0;34m.\u001b[0m\u001b[0mcolab\u001b[0m \u001b[0;32mimport\u001b[0m \u001b[0mauth\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[0;32m----> 6\u001b[0;31m \u001b[0mauth\u001b[0m\u001b[0;34m.\u001b[0m\u001b[0mauthenticate_user\u001b[0m\u001b[0;34m(\u001b[0m\u001b[0;34m)\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[0m\u001b[1;32m      7\u001b[0m \u001b[0;34m\u001b[0m\u001b[0m\n\u001b[1;32m      8\u001b[0m \u001b[0;32mimport\u001b[0m \u001b[0mwikipedia\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n",
            "\u001b[0;32m/usr/local/lib/python3.11/dist-packages/google/colab/auth.py\u001b[0m in \u001b[0;36mauthenticate_user\u001b[0;34m(clear_output, project_id)\u001b[0m\n\u001b[1;32m    258\u001b[0m   \u001b[0;32mif\u001b[0m \u001b[0;32mnot\u001b[0m \u001b[0m_check_adc\u001b[0m\u001b[0;34m(\u001b[0m\u001b[0m_CredentialType\u001b[0m\u001b[0;34m.\u001b[0m\u001b[0mUSER\u001b[0m\u001b[0;34m)\u001b[0m\u001b[0;34m:\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[1;32m    259\u001b[0m     \u001b[0;32mif\u001b[0m \u001b[0muse_auth_ephem\u001b[0m\u001b[0;34m:\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[0;32m--> 260\u001b[0;31m       _message.blocking_request(\n\u001b[0m\u001b[1;32m    261\u001b[0m           \u001b[0;34m'request_auth'\u001b[0m\u001b[0;34m,\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[1;32m    262\u001b[0m           \u001b[0mrequest\u001b[0m\u001b[0;34m=\u001b[0m\u001b[0;34m{\u001b[0m\u001b[0;34m'authType'\u001b[0m\u001b[0;34m:\u001b[0m \u001b[0;34m'auth_user_ephemeral'\u001b[0m\u001b[0;34m}\u001b[0m\u001b[0;34m,\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n",
            "\u001b[0;32m/usr/local/lib/python3.11/dist-packages/google/colab/_message.py\u001b[0m in \u001b[0;36mblocking_request\u001b[0;34m(request_type, request, timeout_sec, parent)\u001b[0m\n\u001b[1;32m    174\u001b[0m       \u001b[0mrequest_type\u001b[0m\u001b[0;34m,\u001b[0m \u001b[0mrequest\u001b[0m\u001b[0;34m,\u001b[0m \u001b[0mparent\u001b[0m\u001b[0;34m=\u001b[0m\u001b[0mparent\u001b[0m\u001b[0;34m,\u001b[0m \u001b[0mexpect_reply\u001b[0m\u001b[0;34m=\u001b[0m\u001b[0;32mTrue\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[1;32m    175\u001b[0m   )\n\u001b[0;32m--> 176\u001b[0;31m   \u001b[0;32mreturn\u001b[0m \u001b[0mread_reply_from_input\u001b[0m\u001b[0;34m(\u001b[0m\u001b[0mrequest_id\u001b[0m\u001b[0;34m,\u001b[0m \u001b[0mtimeout_sec\u001b[0m\u001b[0;34m)\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[0m",
            "\u001b[0;32m/usr/local/lib/python3.11/dist-packages/google/colab/_message.py\u001b[0m in \u001b[0;36mread_reply_from_input\u001b[0;34m(message_id, timeout_sec)\u001b[0m\n\u001b[1;32m    101\u001b[0m     ):\n\u001b[1;32m    102\u001b[0m       \u001b[0;32mif\u001b[0m \u001b[0;34m'error'\u001b[0m \u001b[0;32min\u001b[0m \u001b[0mreply\u001b[0m\u001b[0;34m:\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[0;32m--> 103\u001b[0;31m         \u001b[0;32mraise\u001b[0m \u001b[0mMessageError\u001b[0m\u001b[0;34m(\u001b[0m\u001b[0mreply\u001b[0m\u001b[0;34m[\u001b[0m\u001b[0;34m'error'\u001b[0m\u001b[0;34m]\u001b[0m\u001b[0;34m)\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[0m\u001b[1;32m    104\u001b[0m       \u001b[0;32mreturn\u001b[0m \u001b[0mreply\u001b[0m\u001b[0;34m.\u001b[0m\u001b[0mget\u001b[0m\u001b[0;34m(\u001b[0m\u001b[0;34m'data'\u001b[0m\u001b[0;34m,\u001b[0m \u001b[0;32mNone\u001b[0m\u001b[0;34m)\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[1;32m    105\u001b[0m \u001b[0;34m\u001b[0m\u001b[0m\n",
            "\u001b[0;31mMessageError\u001b[0m: Error: credential propagation was unsuccessful"
          ]
        }
      ],
      "source": [
        "# Install dependencies\n",
        "!pip install google-cloud-aiplatform wikipedia langchain faiss-cpu gradio transformers --quiet\n",
        "\n",
        "# Authenticate and import\n",
        "from google.colab import auth\n",
        "auth.authenticate_user()\n",
        "\n",
        "import wikipedia\n",
        "import gradio as gr\n",
        "from langchain.vectorstores import FAISS\n",
        "from langchain.embeddings import HuggingFaceEmbeddings\n",
        "from langchain.docstore.document import Document\n",
        "from langchain.chains import RetrievalQA\n",
        "from langchain.llms.base import LLM\n",
        "import vertexai\n",
        "from vertexai.language_models import ChatModel\n",
        "\n",
        "# Initialize Vertex AI\n",
        "PROJECT_ID = \"your-gcp-project-id\"  # <<< REPLACE THIS WITH YOUR GCP PROJECT ID\n",
        "REGION = \"us-central1\"\n",
        "vertexai.init(project=PROJECT_ID, location=REGION)\n",
        "\n",
        "# Gemini wrapper for LangChain\n",
        "class GeminiLLM(LLM):\n",
        "    def __init__(self, model_name=\"gemini-1.0-pro\", temperature=0.7):\n",
        "        self.chat_model = ChatModel.from_pretrained(model_name)\n",
        "        self.chat = self.chat_model.start_chat()\n",
        "        self.temperature = temperature\n",
        "    def _call(self, prompt: str, stop=None):\n",
        "        response = self.chat.send_message(prompt)\n",
        "        return response.text\n",
        "    @property\n",
        "    def _llm_type(self):\n",
        "        return \"gemini\"\n",
        "\n",
        "# Wikipedia and FAISS functions\n",
        "def get_wikipedia_content(query, sentences=10):\n",
        "    try:\n",
        "        summary = wikipedia.summary(query, sentences=sentences, auto_suggest=True, redirect=True)\n",
        "        return Document(page_content=summary, metadata={\"source\": \"Wikipedia\", \"topic\": query})\n",
        "    except wikipedia.exceptions.PageError:\n",
        "        return None\n",
        "\n",
        "def create_vectorstore(documents):\n",
        "    embeddings = HuggingFaceEmbeddings(model_name=\"sentence-transformers/all-MiniLM-L6-v2\")\n",
        "    return FAISS.from_documents(documents, embeddings)\n",
        "\n",
        "# Load Gemini and initialize global chatbot state\n",
        "llm = GeminiLLM()\n",
        "retriever = None\n",
        "qa_chain = None\n",
        "current_topic = \"\"\n",
        "\n",
        "# Setup and answer functions\n",
        "def setup_chatbot(topic):\n",
        "    global retriever, qa_chain, current_topic\n",
        "    doc = get_wikipedia_content(topic)\n",
        "    if doc is None:\n",
        "        return \"Couldn't find that topic on Wikipedia.\"\n",
        "    vectorstore = create_vectorstore([doc])\n",
        "    retriever = vectorstore.as_retriever(search_kwargs={\"k\": 1})\n",
        "    qa_chain = RetrievalQA.from_chain_type(llm=llm, retriever=retriever)\n",
        "    current_topic = topic\n",
        "    return f\"Gemini is ready! Ask anything about **{topic}**.\"\n",
        "\n",
        "def answer_question(user_question):\n",
        "    if qa_chain is None:\n",
        "        return \"Please set a topic first using the box above.\"\n",
        "    return qa_chain.run(user_question)\n",
        "\n",
        "# Gradio Interface\n",
        "with gr.Blocks() as demo:\n",
        "    gr.Markdown(\"# Wikipedia Chatbot (Gemini + LangChain + FAISS)\")\n",
        "    with gr.Row():\n",
        "        topic_input = gr.Textbox(label=\"Wikipedia Topic (e.g. Alan Turing)\")\n",
        "        setup_btn = gr.Button(\"Load Topic\")\n",
        "    chatbot_output = gr.Textbox(label=\"System Message\", interactive=False)\n",
        "    with gr.Row():\n",
        "        question_input = gr.Textbox(label=\"Your Question\")\n",
        "        answer_output = gr.Textbox(label=\"Answer\", interactive=False)\n",
        "    setup_btn.click(fn=setup_chatbot, inputs=topic_input, outputs=chatbot_output)\n",
        "    question_input.submit(fn=answer_question, inputs=question_input, outputs=answer_output)\n",
        "\n",
        "demo.launch()"
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 1000
        },
        "id": "WqSP9av9ov79",
        "outputId": "3cf8edcd-5e0e-4098-86f8-267d0269b295"
      },
      "outputs": [
        {
          "name": "stdout",
          "output_type": "stream",
          "text": [
            "Collecting langchain_community\n",
            "  Downloading langchain_community-0.3.21-py3-none-any.whl.metadata (2.4 kB)\n",
            "Collecting langchain-core<1.0.0,>=0.3.51 (from langchain_community)\n",
            "  Downloading langchain_core-0.3.51-py3-none-any.whl.metadata (5.9 kB)\n",
            "Collecting langchain<1.0.0,>=0.3.23 (from langchain_community)\n",
            "  Downloading langchain-0.3.23-py3-none-any.whl.metadata (7.8 kB)\n",
            "Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (2.0.40)\n",
            "Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (2.32.3)\n",
            "Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (6.0.2)\n",
            "Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (3.11.15)\n",
            "Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (9.1.2)\n",
            "Collecting dataclasses-json<0.7,>=0.5.7 (from langchain_community)\n",
            "  Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)\n",
            "Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain_community)\n",
            "  Downloading pydantic_settings-2.8.1-py3-none-any.whl.metadata (3.5 kB)\n",
            "Requirement already satisfied: langsmith<0.4,>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (0.3.23)\n",
            "Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain_community)\n",
            "  Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)\n",
            "Requirement already satisfied: numpy<3,>=1.26.2 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (2.0.2)\n",
            "Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)\n",
            "Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.2)\n",
            "Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.3.0)\n",
            "Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.5.0)\n",
            "Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.2.0)\n",
            "Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.3.1)\n",
            "Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.18.3)\n",
            "Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)\n",
            "  Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)\n",
            "Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)\n",
            "  Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)\n",
            "Collecting langchain-text-splitters<1.0.0,>=0.3.8 (from langchain<1.0.0,>=0.3.23->langchain_community)\n",
            "  Downloading langchain_text_splitters-0.3.8-py3-none-any.whl.metadata (1.9 kB)\n",
            "Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.23->langchain_community) (2.11.2)\n",
            "Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.51->langchain_community) (1.33)\n",
            "Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.51->langchain_community) (24.2)\n",
            "Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.51->langchain_community) (4.13.1)\n",
            "Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain_community) (0.28.1)\n",
            "Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain_community) (3.10.16)\n",
            "Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain_community) (1.0.0)\n",
            "Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain_community) (0.23.0)\n",
            "Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain_community)\n",
            "  Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)\n",
            "Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community) (3.4.1)\n",
            "Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community) (3.10)\n",
            "Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community) (2.3.0)\n",
            "Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community) (2025.1.31)\n",
            "Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.1.1)\n",
            "Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (4.9.0)\n",
            "Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (1.0.7)\n",
            "Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (0.14.0)\n",
            "Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.51->langchain_community) (3.0.0)\n",
            "Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.23->langchain_community) (0.7.0)\n",
            "Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.23->langchain_community) (2.33.1)\n",
            "Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.23->langchain_community) (0.4.0)\n",
            "Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community)\n",
            "  Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)\n",
            "Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (1.3.1)\n",
            "Downloading langchain_community-0.3.21-py3-none-any.whl (2.5 MB)\n",
            "\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m2.5/2.5 MB\u001b[0m \u001b[31m28.9 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
            "\u001b[?25hDownloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)\n",
            "Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)\n",
            "Downloading langchain-0.3.23-py3-none-any.whl (1.0 MB)\n",
            "\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m1.0/1.0 MB\u001b[0m \u001b[31m37.6 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
            "\u001b[?25hDownloading langchain_core-0.3.51-py3-none-any.whl (423 kB)\n",
            "\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m423.3/423.3 kB\u001b[0m \u001b[31m22.9 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
            "\u001b[?25hDownloading pydantic_settings-2.8.1-py3-none-any.whl (30 kB)\n",
            "Downloading langchain_text_splitters-0.3.8-py3-none-any.whl (32 kB)\n",
            "Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)\n",
            "\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m50.9/50.9 kB\u001b[0m \u001b[31m2.7 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
            "\u001b[?25hDownloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)\n",
            "Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)\n",
            "Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)\n",
            "Installing collected packages: python-dotenv, mypy-extensions, marshmallow, httpx-sse, typing-inspect, pydantic-settings, dataclasses-json, langchain-core, langchain-text-splitters, langchain, langchain_community\n",
            "  Attempting uninstall: langchain-core\n",
            "    Found existing installation: langchain-core 0.3.50\n",
            "    Uninstalling langchain-core-0.3.50:\n",
            "      Successfully uninstalled langchain-core-0.3.50\n",
            "  Attempting uninstall: langchain-text-splitters\n",
            "    Found existing installation: langchain-text-splitters 0.3.7\n",
            "    Uninstalling langchain-text-splitters-0.3.7:\n",
            "      Successfully uninstalled langchain-text-splitters-0.3.7\n",
            "  Attempting uninstall: langchain\n",
            "    Found existing installation: langchain 0.3.22\n",
            "    Uninstalling langchain-0.3.22:\n",
            "      Successfully uninstalled langchain-0.3.22\n",
            "Successfully installed dataclasses-json-0.6.7 httpx-sse-0.4.0 langchain-0.3.23 langchain-core-0.3.51 langchain-text-splitters-0.3.8 langchain_community-0.3.21 marshmallow-3.26.1 mypy-extensions-1.0.0 pydantic-settings-2.8.1 python-dotenv-1.1.0 typing-inspect-0.9.0\n"
          ]
        },
        {
          "ename": "ValueError",
          "evalue": "\"GeminiLLM\" object has no field \"temperature\"",
          "output_type": "error",
          "traceback": [
            "\u001b[0;31m---------------------------------------------------------------------------\u001b[0m",
            "\u001b[0;31mValueError\u001b[0m                                Traceback (most recent call last)",
            "\u001b[0;32m<ipython-input-2-0cb0a4aa206c>\u001b[0m in \u001b[0;36m<cell line: 0>\u001b[0;34m()\u001b[0m\n\u001b[1;32m     75\u001b[0m \u001b[0;34m\u001b[0m\u001b[0m\n\u001b[1;32m     76\u001b[0m \u001b[0;31m# ---- STEP 6: Set up chatbot logic ----\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[0;32m---> 77\u001b[0;31m \u001b[0mllm\u001b[0m \u001b[0;34m=\u001b[0m \u001b[0mGeminiLLM\u001b[0m\u001b[0;34m(\u001b[0m\u001b[0;34m)\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[0m\u001b[1;32m     78\u001b[0m \u001b[0mretriever\u001b[0m \u001b[0;34m=\u001b[0m \u001b[0;32mNone\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[1;32m     79\u001b[0m \u001b[0mqa_chain\u001b[0m \u001b[0;34m=\u001b[0m \u001b[0;32mNone\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n",
            "\u001b[0;32m<ipython-input-2-0cb0a4aa206c>\u001b[0m in \u001b[0;36m__init__\u001b[0;34m(self, temperature)\u001b[0m\n\u001b[1;32m     22\u001b[0m \u001b[0;32mclass\u001b[0m \u001b[0mGeminiLLM\u001b[0m\u001b[0;34m(\u001b[0m\u001b[0mLLM\u001b[0m\u001b[0;34m)\u001b[0m\u001b[0;34m:\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[1;32m     23\u001b[0m     \u001b[0;32mdef\u001b[0m \u001b[0m__init__\u001b[0m\u001b[0;34m(\u001b[0m\u001b[0mself\u001b[0m\u001b[0;34m,\u001b[0m \u001b[0mtemperature\u001b[0m\u001b[0;34m=\u001b[0m\u001b[0;36m0.7\u001b[0m\u001b[0;34m)\u001b[0m\u001b[0;34m:\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[0;32m---> 24\u001b[0;31m         \u001b[0mself\u001b[0m\u001b[0;34m.\u001b[0m\u001b[0mtemperature\u001b[0m \u001b[0;34m=\u001b[0m \u001b[0mtemperature\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[0m\u001b[1;32m     25\u001b[0m         \u001b[0;31m# This endpoint is based on available documentation – it may change over time.\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[1;32m     26\u001b[0m         \u001b[0mself\u001b[0m\u001b[0;34m.\u001b[0m\u001b[0mapi_url\u001b[0m \u001b[0;34m=\u001b[0m \u001b[0;34m\"https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent\"\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n",
            "\u001b[0;32m/usr/local/lib/python3.11/dist-packages/pydantic/main.py\u001b[0m in \u001b[0;36m__setattr__\u001b[0;34m(self, name, value)\u001b[0m\n\u001b[1;32m    998\u001b[0m                 \u001b[0msetattr_handler\u001b[0m\u001b[0;34m(\u001b[0m\u001b[0mself\u001b[0m\u001b[0;34m,\u001b[0m \u001b[0mname\u001b[0m\u001b[0;34m,\u001b[0m \u001b[0mvalue\u001b[0m\u001b[0;34m)\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[1;32m    999\u001b[0m             \u001b[0;31m# if None is returned from _setattr_handler, the attribute was set directly\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[0;32m-> 1000\u001b[0;31m             \u001b[0;32melif\u001b[0m \u001b[0;34m(\u001b[0m\u001b[0msetattr_handler\u001b[0m \u001b[0;34m:=\u001b[0m \u001b[0mself\u001b[0m\u001b[0;34m.\u001b[0m\u001b[0m_setattr_handler\u001b[0m\u001b[0;34m(\u001b[0m\u001b[0mname\u001b[0m\u001b[0;34m,\u001b[0m \u001b[0mvalue\u001b[0m\u001b[0;34m)\u001b[0m\u001b[0;34m)\u001b[0m \u001b[0;32mis\u001b[0m \u001b[0;32mnot\u001b[0m \u001b[0;32mNone\u001b[0m\u001b[0;34m:\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[0m\u001b[1;32m   1001\u001b[0m                 \u001b[0msetattr_handler\u001b[0m\u001b[0;34m(\u001b[0m\u001b[0mself\u001b[0m\u001b[0;34m,\u001b[0m \u001b[0mname\u001b[0m\u001b[0;34m,\u001b[0m \u001b[0mvalue\u001b[0m\u001b[0;34m)\u001b[0m  \u001b[0;31m# call here to not memo on possibly unknown fields\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[1;32m   1002\u001b[0m                 \u001b[0mself\u001b[0m\u001b[0;34m.\u001b[0m\u001b[0m__pydantic_setattr_handlers__\u001b[0m\u001b[0;34m[\u001b[0m\u001b[0mname\u001b[0m\u001b[0;34m]\u001b[0m \u001b[0;34m=\u001b[0m \u001b[0msetattr_handler\u001b[0m  \u001b[0;31m# memoize the handler for faster access\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n",
            "\u001b[0;32m/usr/local/lib/python3.11/dist-packages/pydantic/main.py\u001b[0m in \u001b[0;36m_setattr_handler\u001b[0;34m(self, name, value)\u001b[0m\n\u001b[1;32m   1045\u001b[0m                 \u001b[0;32mif\u001b[0m \u001b[0mcls\u001b[0m\u001b[0;34m.\u001b[0m\u001b[0mmodel_config\u001b[0m\u001b[0;34m.\u001b[0m\u001b[0mget\u001b[0m\u001b[0;34m(\u001b[0m\u001b[0;34m'extra'\u001b[0m\u001b[0;34m)\u001b[0m \u001b[0;34m!=\u001b[0m \u001b[0;34m'allow'\u001b[0m\u001b[0;34m:\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[1;32m   1046\u001b[0m                     \u001b[0;31m# TODO - matching error\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[0;32m-> 1047\u001b[0;31m                     \u001b[0;32mraise\u001b[0m \u001b[0mValueError\u001b[0m\u001b[0;34m(\u001b[0m\u001b[0;34mf'\"{cls.__name__}\" object has no field \"{name}\"'\u001b[0m\u001b[0;34m)\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[0m\u001b[1;32m   1048\u001b[0m                 \u001b[0;32melif\u001b[0m \u001b[0mattr\u001b[0m \u001b[0;32mis\u001b[0m \u001b[0;32mNone\u001b[0m\u001b[0;34m:\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[1;32m   1049\u001b[0m                     \u001b[0;31m# attribute does not exist, so put it in extra\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n",
            "\u001b[0;31mValueError\u001b[0m: \"GeminiLLM\" object has no field \"temperature\""
          ]
        }
      ],
      "source": [
        "# ---- ALL-IN-ONE Gemini Wikipedia Chatbot (Colab-Ready, No UI) ----\n",
        "\n",
        "# STEP 1: Install dependencies\n",
        "!pip install wikipedia langchain faiss-cpu transformers openai --quiet\n",
        "!pip install langchain_community\n",
        "\n",
        "# STEP 2: Imports and set up environment\n",
        "import os\n",
        "import requests\n",
        "import wikipedia\n",
        "from langchain.vectorstores import FAISS\n",
        "from langchain.embeddings import HuggingFaceEmbeddings\n",
        "from langchain.docstore.document import Document\n",
        "from langchain.chains import RetrievalQA\n",
        "from langchain.llms.base import LLM\n",
        "\n",
        "# ---- STEP 3: Enter your Gemini API key here ----\n",
        "GEMINI_API_KEY = \"AIzaSyCW5HzSyVUTqh7VbS6nFUiJsoo2fKSjbwM\"  # <<< Replace with your valid Gemini API key\n",
        "os.environ[\"GEMINI_API_KEY\"] = GEMINI_API_KEY\n",
        "\n",
        "# ---- STEP 4: Gemini wrapper using API key ----\n",
        "class GeminiLLM(LLM):\n",
        "    def __init__(self, temperature=0.7):\n",
        "        self.temperature = temperature\n",
        "        # This endpoint is based on available documentation – it may change over time.\n",
        "        self.api_url = \"https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent\"\n",
        "        self.api_key = os.environ.get(\"GEMINI_API_KEY\")\n",
        "        if not self.api_key:\n",
        "            raise ValueError(\"GEMINI_API_KEY not set. Please set it in the code.\")\n",
        "\n",
        "    def _call(self, prompt: str, stop=None):\n",
        "        headers = {\"Content-Type\": \"application/json\"}\n",
        "        params = {\"key\": self.api_key}\n",
        "        body = {\n",
        "            \"contents\": [\n",
        "                {\n",
        "                    \"parts\": [\n",
        "                        {\"text\": prompt}\n",
        "                    ]\n",
        "                }\n",
        "            ],\n",
        "            \"generationConfig\": {\"temperature\": self.temperature}\n",
        "        }\n",
        "        try:\n",
        "            response = requests.post(self.api_url, headers=headers, params=params, json=body)\n",
        "            # Debug: print status code if needed.\n",
        "            # print(\"Response status code:\", response.status_code)\n",
        "            if response.status_code == 200:\n",
        "                data = response.json()\n",
        "                # Debug: Uncomment to see full response\n",
        "                # print(\"Response data:\", data)\n",
        "                # Adjust parsing if response structure changes\n",
        "                return data[\"candidates\"][0][\"content\"][\"parts\"][0][\"text\"]\n",
        "            else:\n",
        "                return f\"[Gemini API Error] {response.status_code}: {response.text}\"\n",
        "        except Exception as e:\n",
        "            return f\"[Gemini API Exception] {str(e)}\"\n",
        "\n",
        "    @property\n",
        "    def _llm_type(self):\n",
        "        return \"gemini\"\n",
        "\n",
        "# ---- STEP 5: Functions for Wikipedia and FAISS ----\n",
        "def get_wikipedia_content(query, sentences=10):\n",
        "    try:\n",
        "        summary = wikipedia.summary(query, sentences=sentences, auto_suggest=True, redirect=True)\n",
        "        return Document(page_content=summary, metadata={\"source\": \"Wikipedia\", \"topic\": query})\n",
        "    except Exception as e:\n",
        "        print(f\"Error retrieving Wikipedia content for '{query}': {e}\")\n",
        "        return None\n",
        "\n",
        "def create_vectorstore(documents):\n",
        "    embeddings = HuggingFaceEmbeddings(model_name=\"sentence-transformers/all-MiniLM-L6-v2\")\n",
        "    return FAISS.from_documents(documents, embeddings)\n",
        "\n",
        "# ---- STEP 6: Set up chatbot logic ----\n",
        "llm = GeminiLLM()\n",
        "retriever = None\n",
        "qa_chain = None\n",
        "current_topic = \"\"\n",
        "\n",
        "def setup_chatbot(topic):\n",
        "    global retriever, qa_chain, current_topic\n",
        "    doc = get_wikipedia_content(topic)\n",
        "    if doc is None:\n",
        "        return f\"❌ No Wikipedia page found for '{topic}'.\"\n",
        "    vectorstore = create_vectorstore([doc])\n",
        "    retriever = vectorstore.as_retriever(search_kwargs={\"k\": 1})\n",
        "    qa_chain = RetrievalQA.from_chain_type(llm=llm, retriever=retriever)\n",
        "    current_topic = topic\n",
        "    return f\"✅ Chatbot is ready! Ask anything about **{topic}**.\"\n",
        "\n",
        "def answer_question(user_question):\n",
        "    if qa_chain is None:\n",
        "        return \"⚠️ Please run setup_chatbot('your topic') first.\"\n",
        "    return qa_chain.run(user_question)\n",
        "\n",
        "# ---- STEP 7: Example usage ----\n",
        "print(setup_chatbot(\"Nikola Tesla\"))\n",
        "print(answer_question(\"What did he invent?\"))"
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 655
        },
        "id": "A1msUpb8tkZi",
        "outputId": "bf74fa92-fabb-484e-eae7-89d2df2f8f64"
      },
      "outputs": [
        {
          "ename": "ValueError",
          "evalue": "\"GeminiLLM\" object has no field \"temperature\"",
          "output_type": "error",
          "traceback": [
            "\u001b[0;31m---------------------------------------------------------------------------\u001b[0m",
            "\u001b[0;31mValueError\u001b[0m                                Traceback (most recent call last)",
            "\u001b[0;32m<ipython-input-3-02e9a3edb355>\u001b[0m in \u001b[0;36m<cell line: 0>\u001b[0;34m()\u001b[0m\n\u001b[1;32m     72\u001b[0m \u001b[0;34m\u001b[0m\u001b[0m\n\u001b[1;32m     73\u001b[0m \u001b[0;31m# ---- STEP 6: Chatbot logic ----\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[0;32m---> 74\u001b[0;31m \u001b[0mllm\u001b[0m \u001b[0;34m=\u001b[0m \u001b[0mGeminiLLM\u001b[0m\u001b[0;34m(\u001b[0m\u001b[0;34m)\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[0m\u001b[1;32m     75\u001b[0m \u001b[0mretriever\u001b[0m \u001b[0;34m=\u001b[0m \u001b[0;32mNone\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[1;32m     76\u001b[0m \u001b[0mqa_chain\u001b[0m \u001b[0;34m=\u001b[0m \u001b[0;32mNone\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n",
            "\u001b[0;32m<ipython-input-3-02e9a3edb355>\u001b[0m in \u001b[0;36m__init__\u001b[0;34m(self, temperature)\u001b[0m\n\u001b[1;32m     24\u001b[0m         \u001b[0msuper\u001b[0m\u001b[0;34m(\u001b[0m\u001b[0;34m)\u001b[0m\u001b[0;34m.\u001b[0m\u001b[0m__init__\u001b[0m\u001b[0;34m(\u001b[0m\u001b[0;34m)\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[1;32m     25\u001b[0m         \u001b[0;31m# Now assign the temperature directly on self.__dict__\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[0;32m---> 26\u001b[0;31m         \u001b[0mself\u001b[0m\u001b[0;34m.\u001b[0m\u001b[0mtemperature\u001b[0m \u001b[0;34m=\u001b[0m \u001b[0mtemperature\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[0m\u001b[1;32m     27\u001b[0m         \u001b[0;31m# API endpoint based on available documentation (subject to change)\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[1;32m     28\u001b[0m         \u001b[0mself\u001b[0m\u001b[0;34m.\u001b[0m\u001b[0mapi_url\u001b[0m \u001b[0;34m=\u001b[0m \u001b[0;34m\"https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent\"\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n",
            "\u001b[0;32m/usr/local/lib/python3.11/dist-packages/pydantic/main.py\u001b[0m in \u001b[0;36m__setattr__\u001b[0;34m(self, name, value)\u001b[0m\n\u001b[1;32m    998\u001b[0m                 \u001b[0msetattr_handler\u001b[0m\u001b[0;34m(\u001b[0m\u001b[0mself\u001b[0m\u001b[0;34m,\u001b[0m \u001b[0mname\u001b[0m\u001b[0;34m,\u001b[0m \u001b[0mvalue\u001b[0m\u001b[0;34m)\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[1;32m    999\u001b[0m             \u001b[0;31m# if None is returned from _setattr_handler, the attribute was set directly\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[0;32m-> 1000\u001b[0;31m             \u001b[0;32melif\u001b[0m \u001b[0;34m(\u001b[0m\u001b[0msetattr_handler\u001b[0m \u001b[0;34m:=\u001b[0m \u001b[0mself\u001b[0m\u001b[0;34m.\u001b[0m\u001b[0m_setattr_handler\u001b[0m\u001b[0;34m(\u001b[0m\u001b[0mname\u001b[0m\u001b[0;34m,\u001b[0m \u001b[0mvalue\u001b[0m\u001b[0;34m)\u001b[0m\u001b[0;34m)\u001b[0m \u001b[0;32mis\u001b[0m \u001b[0;32mnot\u001b[0m \u001b[0;32mNone\u001b[0m\u001b[0;34m:\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[0m\u001b[1;32m   1001\u001b[0m                 \u001b[0msetattr_handler\u001b[0m\u001b[0;34m(\u001b[0m\u001b[0mself\u001b[0m\u001b[0;34m,\u001b[0m \u001b[0mname\u001b[0m\u001b[0;34m,\u001b[0m \u001b[0mvalue\u001b[0m\u001b[0;34m)\u001b[0m  \u001b[0;31m# call here to not memo on possibly unknown fields\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[1;32m   1002\u001b[0m                 \u001b[0mself\u001b[0m\u001b[0;34m.\u001b[0m\u001b[0m__pydantic_setattr_handlers__\u001b[0m\u001b[0;34m[\u001b[0m\u001b[0mname\u001b[0m\u001b[0;34m]\u001b[0m \u001b[0;34m=\u001b[0m \u001b[0msetattr_handler\u001b[0m  \u001b[0;31m# memoize the handler for faster access\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n",
            "\u001b[0;32m/usr/local/lib/python3.11/dist-packages/pydantic/main.py\u001b[0m in \u001b[0;36m_setattr_handler\u001b[0;34m(self, name, value)\u001b[0m\n\u001b[1;32m   1045\u001b[0m                 \u001b[0;32mif\u001b[0m \u001b[0mcls\u001b[0m\u001b[0;34m.\u001b[0m\u001b[0mmodel_config\u001b[0m\u001b[0;34m.\u001b[0m\u001b[0mget\u001b[0m\u001b[0;34m(\u001b[0m\u001b[0;34m'extra'\u001b[0m\u001b[0;34m)\u001b[0m \u001b[0;34m!=\u001b[0m \u001b[0;34m'allow'\u001b[0m\u001b[0;34m:\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[1;32m   1046\u001b[0m                     \u001b[0;31m# TODO - matching error\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[0;32m-> 1047\u001b[0;31m                     \u001b[0;32mraise\u001b[0m \u001b[0mValueError\u001b[0m\u001b[0;34m(\u001b[0m\u001b[0;34mf'\"{cls.__name__}\" object has no field \"{name}\"'\u001b[0m\u001b[0;34m)\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[0m\u001b[1;32m   1048\u001b[0m                 \u001b[0;32melif\u001b[0m \u001b[0mattr\u001b[0m \u001b[0;32mis\u001b[0m \u001b[0;32mNone\u001b[0m\u001b[0;34m:\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n\u001b[1;32m   1049\u001b[0m                     \u001b[0;31m# attribute does not exist, so put it in extra\u001b[0m\u001b[0;34m\u001b[0m\u001b[0;34m\u001b[0m\u001b[0m\n",
            "\u001b[0;31mValueError\u001b[0m: \"GeminiLLM\" object has no field \"temperature\""
          ]
        }
      ],
      "source": [
        "# ---- ALL-IN-ONE Gemini Wikipedia Chatbot (Colab-Ready, No UI) ----\n",
        "\n",
        "# STEP 1: Install dependencies (including LangChain community extras)\n",
        "!pip install wikipedia langchain[community] faiss-cpu transformers requests --quiet\n",
        "\n",
        "# STEP 2: Imports and environment setup\n",
        "import os\n",
        "import requests\n",
        "import wikipedia\n",
        "from langchain.vectorstores import FAISS\n",
        "from langchain.embeddings import HuggingFaceEmbeddings\n",
        "from langchain.docstore.document import Document\n",
        "from langchain.chains import RetrievalQA\n",
        "from langchain.llms.base import LLM\n",
        "\n",
        "# ---- STEP 3: Enter your Gemini API key here ----\n",
        "GEMINI_API_KEY = \"AIzaSyCW5HzSyVUTqh7VbS6nFUiJsoo2fKSjbwM\"  # <<< Replace with your actual Gemini API key\n",
        "os.environ[\"GEMINI_API_KEY\"] = GEMINI_API_KEY\n",
        "\n",
        "# ---- STEP 4: Gemini wrapper using API key with explicit super().__init__() ----\n",
        "class GeminiLLM(LLM):\n",
        "    def __init__(self, temperature=0.7):\n",
        "        # Call the parent constructor so that attributes are set properly\n",
        "        super().__init__()\n",
        "        # Now assign the temperature directly on self.__dict__\n",
        "        self.temperature = temperature\n",
        "        # API endpoint based on available documentation (subject to change)\n",
        "        self.api_url = \"https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent\"\n",
        "        self.api_key = os.environ.get(\"GEMINI_API_KEY\")\n",
        "        if not self.api_key:\n",
        "            raise ValueError(\"GEMINI_API_KEY not set. Please set it in the code.\")\n",
        "\n",
        "    def _call(self, prompt: str, stop=None):\n",
        "        headers = {\"Content-Type\": \"application/json\"}\n",
        "        params = {\"key\": self.api_key}\n",
        "        body = {\n",
        "            \"contents\": [\n",
        "                {\n",
        "                    \"parts\": [\n",
        "                        {\"text\": prompt}\n",
        "                    ]\n",
        "                }\n",
        "            ],\n",
        "            \"generationConfig\": {\"temperature\": self.temperature}\n",
        "        }\n",
        "        try:\n",
        "            response = requests.post(self.api_url, headers=headers, params=params, json=body)\n",
        "            if response.status_code == 200:\n",
        "                data = response.json()\n",
        "                return data[\"candidates\"][0][\"content\"][\"parts\"][0][\"text\"]\n",
        "            else:\n",
        "                return f\"[Gemini API Error] {response.status_code}: {response.text}\"\n",
        "        except Exception as e:\n",
        "            return f\"[Gemini API Exception] {str(e)}\"\n",
        "\n",
        "    @property\n",
        "    def _llm_type(self):\n",
        "        return \"gemini\"\n",
        "\n",
        "# ---- STEP 5: Helper functions for Wikipedia and FAISS ----\n",
        "def get_wikipedia_content(query, sentences=10):\n",
        "    try:\n",
        "        summary = wikipedia.summary(query, sentences=sentences, auto_suggest=True, redirect=True)\n",
        "        return Document(page_content=summary, metadata={\"source\": \"Wikipedia\", \"topic\": query})\n",
        "    except Exception as e:\n",
        "        print(f\"Error retrieving Wikipedia content for '{query}': {e}\")\n",
        "        return None\n",
        "\n",
        "def create_vectorstore(documents):\n",
        "    embeddings = HuggingFaceEmbeddings(model_name=\"sentence-transformers/all-MiniLM-L6-v2\")\n",
        "    return FAISS.from_documents(documents, embeddings)\n",
        "\n",
        "# ---- STEP 6: Chatbot logic ----\n",
        "llm = GeminiLLM()\n",
        "retriever = None\n",
        "qa_chain = None\n",
        "current_topic = \"\"\n",
        "\n",
        "def setup_chatbot(topic):\n",
        "    global retriever, qa_chain, current_topic\n",
        "    doc = get_wikipedia_content(topic)\n",
        "    if doc is None:\n",
        "        return f\"❌ No Wikipedia page found for '{topic}'.\"\n",
        "    vectorstore = create_vectorstore([doc])\n",
        "    retriever = vectorstore.as_retriever(search_kwargs={\"k\": 1})\n",
        "    qa_chain = RetrievalQA.from_chain_type(llm=llm, retriever=retriever)\n",
        "    current_topic = topic\n",
        "    return f\"✅ Chatbot is ready! Ask anything about **{topic}**.\"\n",
        "\n",
        "def answer_question(user_question):\n",
        "    if qa_chain is None:\n",
        "        return \"⚠️ Please run setup_chatbot('your topic') first.\"\n",
        "    return qa_chain.run(user_question)\n",
        "\n",
        "# ---- STEP 7: Example usage ----\n",
        "print(setup_chatbot(\"Nikola Tesla\"))\n",
        "print(answer_question(\"What did he invent?\"))"
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "metadata": {
        "id": "kH_XJkepv3cr"
      },
      "outputs": [],
      "source": [
        "# Wikipedia Chatbot with Gemini LLM using LangChain\n",
        "# This notebook creates a chatbot that answers queries using Wikipedia data\n",
        "\n",
        "# Install necessary packages\n",
        "!pip install -q langchain langchain-google-genai faiss-cpu wikipedia-api sentence-transformers\n",
        "\n",
        "# Import required libraries\n",
        "import os\n",
        "import wikipedia\n",
        "import google.generativeai as genai\n",
        "from langchain.vectorstores import FAISS\n",
        "from langchain.embeddings import HuggingFaceEmbeddings\n",
        "from langchain.text_splitter import RecursiveCharacterTextSplitter\n",
        "from langchain_google_genai import GoogleGenerativeAIEmbeddings, ChatGoogleGenerativeAI\n",
        "from langchain.chains import ConversationalRetrievalChain\n",
        "from langchain.memory import ConversationBufferMemory\n",
        "from IPython.display import display, Markdown\n",
        "import warnings\n",
        "warnings.filterwarnings('ignore')\n",
        "\n",
        "# Set up Google API key\n",
        "# You'll need to get an API key from https://makersuite.google.com/app/apikey\n",
        "GOOGLE_API_KEY = \"# Wikipedia Chatbot with Gemini LLM using LangChain\n",
        "# This notebook creates a chatbot that answers queries using Wikipedia data\n",
        "\n",
        "# Install necessary packages\n",
        "!pip install -q langchain langchain-google-genai faiss-cpu wikipedia-api sentence-transformers\n",
        "\n",
        "# Import required libraries\n",
        "import os\n",
        "import wikipedia\n",
        "import google.generativeai as genai\n",
        "from langchain.vectorstores import FAISS\n",
        "from langchain.embeddings import HuggingFaceEmbeddings\n",
        "from langchain.text_splitter import RecursiveCharacterTextSplitter\n",
        "from langchain_google_genai import GoogleGenerativeAIEmbeddings, ChatGoogleGenerativeAI\n",
        "from langchain.chains import ConversationalRetrievalChain\n",
        "from langchain.memory import ConversationBufferMemory\n",
        "from IPython.display import display, Markdown\n",
        "import warnings\n",
        "warnings.filterwarnings('ignore')\n",
        "\n",
        "# Set up Google API key\n",
        "# You'll need to get an API key from https://makersuite.google.com/app/apikey\n",
        "GOOGLE_API_KEY = \"your_google_api_key_here\"  # Replace with your actual API key\n",
        "os.environ[\"GOOGLE_API_KEY\"] = GOOGLE_API_KEY\n",
        "genai.configure(api_key=GOOGLE_API_KEY)\n",
        "\n",
        "# Function to fetch Wikipedia data for a given topic\n",
        "def fetch_wikipedia_content(query, num_results=3):\n",
        "    print(f\"Searching Wikipedia for: {query}\")\n",
        "\n",
        "    # Search for Wikipedia pages related to the query\n",
        "    search_results = wikipedia.search(query, results=num_results)\n",
        "\n",
        "    if not search_results:\n",
        "        return \"No Wikipedia results found for the query.\"\n",
        "\n",
        "    all_content = \"\"\n",
        "\n",
        "    # For each search result, try to get the page content\n",
        "    for title in search_results:\n",
        "        try:\n",
        "            # Get the Wikipedia page\n",
        "            page = wikipedia.page(title, auto_suggest=False)\n",
        "\n",
        "            # Add page title and content to our collection\n",
        "            all_content += f\"Title: {page.title}\\n\\nContent:\\n{page.content}\\n\\n\"\n",
        "            print(f\"Added content from: {page.title}\")\n",
        "        except Exception as e:\n",
        "            print(f\"Error fetching {title}: {str(e)}\")\n",
        "            continue\n",
        "\n",
        "    return all_content\n",
        "\n",
        "# Create embeddings using Sentence Transformers (alternative to GoogleGenerativeAIEmbeddings)\n",
        "def create_vector_db(text_chunks):\n",
        "    embeddings = HuggingFaceEmbeddings(\n",
        "        model_name=\"all-MiniLM-L6-v2\",\n",
        "        model_kwargs={'device': 'cpu'}\n",
        "    )\n",
        "\n",
        "    # Create the FAISS vector store\n",
        "    vector_store = FAISS.from_texts(texts=text_chunks, embedding=embeddings)\n",
        "    return vector_store\n",
        "\n",
        "# Text splitter function\n",
        "def split_text(text):\n",
        "    text_splitter = RecursiveCharacterTextSplitter(\n",
        "        chunk_size=1000,\n",
        "        chunk_overlap=200,\n",
        "        length_function=len\n",
        "    )\n",
        "    chunks = text_splitter.split_text(text)\n",
        "    return chunks\n",
        "\n",
        "# Set up the Gemini LLM\n",
        "def setup_gemini_llm():\n",
        "    llm = ChatGoogleGenerativeAI(\n",
        "        model=\"gemini-pro\",\n",
        "        temperature=0.2,\n",
        "        top_p=0.85,\n",
        "        top_k=40,\n",
        "        max_output_tokens=2048,\n",
        "        verbose=True\n",
        "    )\n",
        "    return llm\n",
        "\n",
        "# Create a Wikipedia chatbot\n",
        "def create_wikipedia_chatbot(topic):\n",
        "    # 1. Fetch Wikipedia content\n",
        "    wiki_content = fetch_wikipedia_content(topic)\n",
        "\n",
        "    # 2. Split the content into chunks\n",
        "    text_chunks = split_text(wiki_content)\n",
        "    print(f\"Created {len(text_chunks)} text chunks\")\n",
        "\n",
        "    # 3. Create vector store\n",
        "    vector_store = create_vector_db(text_chunks)\n",
        "    print(\"Created FAISS vector store\")\n",
        "\n",
        "    # 4. Set up Gemini LLM\n",
        "    llm = setup_gemini_llm()\n",
        "\n",
        "    # 5. Set up conversation memory\n",
        "    memory = ConversationBufferMemory(\n",
        "        memory_key=\"chat_history\",\n",
        "        return_messages=True\n",
        "    )\n",
        "\n",
        "    # 6. Create conversational chain\n",
        "    conversation_chain = ConversationalRetrievalChain.from_llm(\n",
        "        llm=llm,\n",
        "        retriever=vector_store.as_retriever(search_kwargs={\"k\": 4}),\n",
        "        memory=memory,\n",
        "        return_source_documents=True\n",
        "    )\n",
        "\n",
        "    return conversation_chain\n",
        "\n",
        "# Function to interact with the chatbot\n",
        "def chat_with_wikipedia(conversation_chain, query):\n",
        "    response = conversation_chain({\"question\": query})\n",
        "    answer = response[\"answer\"]\n",
        "\n",
        "    # Print source documents if available\n",
        "    if \"source_documents\" in response:\n",
        "        sources = response.get(\"source_documents\", [])\n",
        "        if sources:\n",
        "            sources_text = \"\\n\\nReferences:\"\n",
        "            for i, doc in enumerate(sources, 1):\n",
        "                sources_text += f\"\\n{i}. Content chunk from Wikipedia\"\n",
        "            answer += sources_text\n",
        "\n",
        "    return answer\n",
        "\n",
        "# Demo: Create a chatbot for a specific topic\n",
        "def run_wikipedia_chatbot(initial_topic=\"Artificial Intelligence\"):\n",
        "    print(f\"Initializing Wikipedia chatbot with topic: {initial_topic}\")\n",
        "    conversation_chain = create_wikipedia_chatbot(initial_topic)\n",
        "\n",
        "    print(\"\\n\" + \"=\"*50)\n",
        "    print(\"Wikipedia Chatbot is ready! Ask questions about the topic.\")\n",
        "    print(\"Type 'new topic: [your topic]' to change the topic.\")\n",
        "    print(\"Type 'exit' to end the conversation.\")\n",
        "    print(\"=\"*50 + \"\\n\")\n",
        "\n",
        "    while True:\n",
        "        user_input = input(\"Your question: \")\n",
        "\n",
        "        if user_input.lower() == 'exit':\n",
        "            print(\"Goodbye!\")\n",
        "            break\n",
        "\n",
        "        # Check if user wants to change the topic\n",
        "        if user_input.lower().startswith(\"new topic:\"):\n",
        "            new_topic = user_input[len(\"new topic:\"):].strip()\n",
        "            print(f\"\\nChanging topic to: {new_topic}\")\n",
        "            conversation_chain = create_wikipedia_chatbot(new_topic)\n",
        "            print(\"Topic changed successfully! Ask a question about the new topic.\\n\")\n",
        "            continue\n",
        "\n",
        "        # Get response from the chatbot\n",
        "        response = chat_with_wikipedia(conversation_chain, user_input)\n",
        "\n",
        "        # Display the response\n",
        "        display(Markdown(response))\n",
        "        print(\"\\n\" + \"-\"*50 + \"\\n\")\n",
        "\n",
        "# Run the chatbot - uncomment to run directly\n",
        "# run_wikipedia_chatbot(\"Quantum Computing\")\n",
        "\n",
        "# Interactive UI with user input (better for Google Colab)\n",
        "from IPython.display import HTML, display\n",
        "import ipywidgets as widgets\n",
        "\n",
        "def create_ui():\n",
        "    # Initialize with AI topic\n",
        "    conversation_chain = create_wikipedia_chatbot(\"Artificial Intelligence\")\n",
        "\n",
        "    # Create output area\n",
        "    output = widgets.Output()\n",
        "\n",
        "    # Create text input\n",
        "    text_input = widgets.Text(\n",
        "        value='',\n",
        "        placeholder='Type your question or \"new topic: [topic]\" to change topics',\n",
        "        description='',\n",
        "        layout=widgets.Layout(width='80%')\n",
        "    )\n",
        "\n",
        "    # Create send button\n",
        "    send_button = widgets.Button(\n",
        "        description='Send',\n",
        "        button_style='primary',\n",
        "        layout=widgets.Layout(width='19%')\n",
        "    )\n",
        "\n",
        "    # Create input area\n",
        "    input_area = widgets.HBox([text_input, send_button])\n",
        "\n",
        "    # Display widgets\n",
        "    display(widgets.VBox([output, input_area]))\n",
        "\n",
        "    with output:\n",
        "        display(Markdown(\"# Wikipedia Chatbot with Gemini\\n\\n**Current topic:** Artificial Intelligence\\n\\nAsk questions or type 'new topic: [your topic]' to change topics\"))\n",
        "\n",
        "    def on_button_click(b):\n",
        "        query = text_input.value\n",
        "        text_input.value = ''\n",
        "\n",
        "        with output:\n",
        "            display(Markdown(f\"**You:** {query}\"))\n",
        "\n",
        "            if query.lower().startswith(\"new topic:\"):\n",
        "                new_topic = query[len(\"new topic:\"):].strip()\n",
        "                display(Markdown(f\"*Changing topic to: {new_topic}...*\"))\n",
        "                nonlocal conversation_chain\n",
        "                conversation_chain = create_wikipedia_chatbot(new_topic)\n",
        "                display(Markdown(f\"**Topic changed to:** {new_topic}\"))\n",
        "            else:\n",
        "                display(Markdown(\"*Thinking...*\"))\n",
        "                try:\n",
        "                    response = chat_with_wikipedia(conversation_chain, query)\n",
        "                    display(Markdown(f\"**Wikipedia Bot:** {response}\"))\n",
        "                except Exception as e:\n",
        "                    display(Markdown(f\"**Error:** {str(e)}\"))\n",
        "\n",
        "            display(Markdown(\"---\"))\n",
        "\n",
        "    send_button.on_click(on_button_click)\n",
        "\n",
        "    def on_enter(sender):\n",
        "        on_button_click(None)\n",
        "\n",
        "    text_input.on_submit(on_enter)\n",
        "\n",
        "# Uncomment to run the interactive UI\n",
        "# create_ui()\n",
        "\n",
        "# Example usage in Colab\n",
        "print(\"Run the following code to start the chatbot:\")\n",
        "print(\"create_ui()\")\"  # Replace with your actual API key\n",
        "os.environ[\"GOOGLE_API_KEY\"] = GOOGLE_API_KEY\n",
        "genai.configure(api_key=GOOGLE_API_KEY)\n",
        "\n",
        "# Function to fetch Wikipedia data for a given topic\n",
        "def fetch_wikipedia_content(query, num_results=3):\n",
        "    print(f\"Searching Wikipedia for: {query}\")\n",
        "\n",
        "    # Search for Wikipedia pages related to the query\n",
        "    search_results = wikipedia.search(query, results=num_results)\n",
        "\n",
        "    if not search_results:\n",
        "        return \"No Wikipedia results found for the query.\"\n",
        "\n",
        "    all_content = \"\"\n",
        "\n",
        "    # For each search result, try to get the page content\n",
        "    for title in search_results:\n",
        "        try:\n",
        "            # Get the Wikipedia page\n",
        "            page = wikipedia.page(title, auto_suggest=False)\n",
        "\n",
        "            # Add page title and content to our collection\n",
        "            all_content += f\"Title: {page.title}\\n\\nContent:\\n{page.content}\\n\\n\"\n",
        "            print(f\"Added content from: {page.title}\")\n",
        "        except Exception as e:\n",
        "            print(f\"Error fetching {title}: {str(e)}\")\n",
        "            continue\n",
        "\n",
        "    return all_content\n",
        "\n",
        "# Create embeddings using Sentence Transformers (alternative to GoogleGenerativeAIEmbeddings)\n",
        "def create_vector_db(text_chunks):\n",
        "    embeddings = HuggingFaceEmbeddings(\n",
        "        model_name=\"all-MiniLM-L6-v2\",\n",
        "        model_kwargs={'device': 'cpu'}\n",
        "    )\n",
        "\n",
        "    # Create the FAISS vector store\n",
        "    vector_store = FAISS.from_texts(texts=text_chunks, embedding=embeddings)\n",
        "    return vector_store\n",
        "\n",
        "# Text splitter function\n",
        "def split_text(text):\n",
        "    text_splitter = RecursiveCharacterTextSplitter(\n",
        "        chunk_size=1000,\n",
        "        chunk_overlap=200,\n",
        "        length_function=len\n",
        "    )\n",
        "    chunks = text_splitter.split_text(text)\n",
        "    return chunks\n",
        "\n",
        "# Set up the Gemini LLM\n",
        "def setup_gemini_llm():\n",
        "    llm = ChatGoogleGenerativeAI(\n",
        "        model=\"gemini-1.5-pro\",\n",
        "        temperature=0.2,\n",
        "        top_p=0.85,\n",
        "        top_k=40,\n",
        "        max_output_tokens=2048,\n",
        "        verbose=True\n",
        "    )\n",
        "    return llm\n",
        "\n",
        "# Create a Wikipedia chatbot\n",
        "def create_wikipedia_chatbot(topic):\n",
        "    # 1. Fetch Wikipedia content\n",
        "    wiki_content = fetch_wikipedia_content(topic)\n",
        "\n",
        "    # 2. Split the content into chunks\n",
        "    text_chunks = split_text(wiki_content)\n",
        "    print(f\"Created {len(text_chunks)} text chunks\")\n",
        "\n",
        "    # 3. Create vector store\n",
        "    vector_store = create_vector_db(text_chunks)\n",
        "    print(\"Created FAISS vector store\")\n",
        "\n",
        "    # 4. Set up Gemini LLM\n",
        "    llm = setup_gemini_llm()\n",
        "\n",
        "    # 5. Set up conversation memory\n",
        "    memory = ConversationBufferMemory(\n",
        "        memory_key=\"chat_history\",\n",
        "        return_messages=True\n",
        "    )\n",
        "\n",
        "    # 6. Create conversational chain\n",
        "    conversation_chain = ConversationalRetrievalChain.from_llm(\n",
        "        llm=llm,\n",
        "        retriever=vector_store.as_retriever(search_kwargs={\"k\": 4}),\n",
        "        memory=memory,\n",
        "        return_source_documents=True\n",
        "    )\n",
        "\n",
        "    return conversation_chain\n",
        "\n",
        "# Function to interact with the chatbot\n",
        "def chat_with_wikipedia(conversation_chain, query):\n",
        "    response = conversation_chain({\"question\": query})\n",
        "    answer = response[\"answer\"]\n",
        "\n",
        "    # Print source documents if available\n",
        "    if \"source_documents\" in response:\n",
        "        sources = response.get(\"source_documents\", [])\n",
        "        if sources:\n",
        "            sources_text = \"\\n\\nReferences:\"\n",
        "            for i, doc in enumerate(sources, 1):\n",
        "                sources_text += f\"\\n{i}. Content chunk from Wikipedia\"\n",
        "            answer += sources_text\n",
        "\n",
        "    return answer\n",
        "\n",
        "# Demo: Create a chatbot for a specific topic\n",
        "def run_wikipedia_chatbot(initial_topic=\"Artificial Intelligence\"):\n",
        "    print(f\"Initializing Wikipedia chatbot with topic: {initial_topic}\")\n",
        "    conversation_chain = create_wikipedia_chatbot(initial_topic)\n",
        "\n",
        "    print(\"\\n\" + \"=\"*50)\n",
        "    print(\"Wikipedia Chatbot is ready! Ask questions about the topic.\")\n",
        "    print(\"Type 'new topic: [your topic]' to change the topic.\")\n",
        "    print(\"Type 'exit' to end the conversation.\")\n",
        "    print(\"=\"*50 + \"\\n\")\n",
        "\n",
        "    while True:\n",
        "        user_input = input(\"Your question: \")\n",
        "\n",
        "        if user_input.lower() == 'exit':\n",
        "            print(\"Goodbye!\")\n",
        "            break\n",
        "\n",
        "        # Check if user wants to change the topic\n",
        "        if user_input.lower().startswith(\"new topic:\"):\n",
        "            new_topic = user_input[len(\"new topic:\"):].strip()\n",
        "            print(f\"\\nChanging topic to: {new_topic}\")\n",
        "            conversation_chain = create_wikipedia_chatbot(new_topic)\n",
        "            print(\"Topic changed successfully! Ask a question about the new topic.\\n\")\n",
        "            continue\n",
        "\n",
        "        # Get response from the chatbot\n",
        "        response = chat_with_wikipedia(conversation_chain, user_input)\n",
        "\n",
        "        # Display the response\n",
        "        display(Markdown(response))\n",
        "        print(\"\\n\" + \"-\"*50 + \"\\n\")\n",
        "\n",
        "# Run the chatbot - uncomment to run directly\n",
        "# run_wikipedia_chatbot(\"Quantum Computing\")\n",
        "\n",
        "# Interactive UI with user input (better for Google Colab)\n",
        "from IPython.display import HTML, display\n",
        "import ipywidgets as widgets\n",
        "\n",
        "def create_ui():\n",
        "    # Initialize with AI topic\n",
        "    conversation_chain = create_wikipedia_chatbot(\"Artificial Intelligence\")\n",
        "\n",
        "    # Create output area\n",
        "    output = widgets.Output()\n",
        "\n",
        "    # Create text input\n",
        "    text_input = widgets.Text(\n",
        "        value='',\n",
        "        placeholder='Type your question or \"new topic: [topic]\" to change topics',\n",
        "        description='',\n",
        "        layout=widgets.Layout(width='80%')\n",
        "    )\n",
        "\n",
        "    # Create send button\n",
        "    send_button = widgets.Button(\n",
        "        description='Send',\n",
        "        button_style='primary',\n",
        "        layout=widgets.Layout(width='19%')\n",
        "    )\n",
        "\n",
        "    # Create input area\n",
        "    input_area = widgets.HBox([text_input, send_button])\n",
        "\n",
        "    # Display widgets\n",
        "    display(widgets.VBox([output, input_area]))\n",
        "\n",
        "    with output:\n",
        "        display(Markdown(\"# Wikipedia Chatbot with Gemini\\n\\n**Current topic:** Artificial Intelligence\\n\\nAsk questions or type 'new topic: [your topic]' to change topics\"))\n",
        "\n",
        "    def on_button_click(b):\n",
        "        query = text_input.value\n",
        "        text_input.value = ''\n",
        "\n",
        "        with output:\n",
        "            display(Markdown(f\"**You:** {query}\"))\n",
        "\n",
        "            if query.lower().startswith(\"new topic:\"):\n",
        "                new_topic = query[len(\"new topic:\"):].strip()\n",
        "                display(Markdown(f\"*Changing topic to: {new_topic}...*\"))\n",
        "                nonlocal conversation_chain\n",
        "                conversation_chain = create_wikipedia_chatbot(new_topic)\n",
        "                display(Markdown(f\"**Topic changed to:** {new_topic}\"))\n",
        "            else:\n",
        "                display(Markdown(\"*Thinking...*\"))\n",
        "                try:\n",
        "                    response = chat_with_wikipedia(conversation_chain, query)\n",
        "                    display(Markdown(f\"**Wikipedia Bot:** {response}\"))\n",
        "                except Exception as e:\n",
        "                    display(Markdown(f\"**Error:** {str(e)}\"))\n",
        "\n",
        "            display(Markdown(\"---\"))\n",
        "\n",
        "    send_button.on_click(on_button_click)\n",
        "\n",
        "    def on_enter(sender):\n",
        "        on_button_click(None)\n",
        "\n",
        "    text_input.on_submit(on_enter)\n",
        "\n",
        "# Uncomment to run the interactive UI\n",
        "# create_ui()\n",
        "\n",
        "# Example usage in Colab\n",
        "print(\"Run the following code to start the chatbot:\")\n",
        "print(\"create_ui()\")"
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "CUSk2LlRweZ4",
        "outputId": "8b3f122e-ad53-4056-b755-fe146cea8128"
      },
      "outputs": [
        {
          "name": "stdout",
          "output_type": "stream",
          "text": [
            "Found existing installation: google-generativeai 0.8.4\n",
            "Uninstalling google-generativeai-0.8.4:\n",
            "  Successfully uninstalled google-generativeai-0.8.4\n",
            "Found existing installation: google-ai-generativelanguage 0.6.17\n",
            "Uninstalling google-ai-generativelanguage-0.6.17:\n",
            "  Successfully uninstalled google-ai-generativelanguage-0.6.17\n",
            "\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m1.3/1.3 MB\u001b[0m \u001b[31m14.0 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
            "\u001b[?25h\u001b[31mERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.\n",
            "langchain-google-genai 2.1.2 requires google-ai-generativelanguage<0.7.0,>=0.6.16, but you have google-ai-generativelanguage 0.6.15 which is incompatible.\u001b[0m\u001b[31m\n",
            "\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m175.4/175.4 kB\u001b[0m \u001b[31m3.0 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
            "\u001b[?25h\u001b[31mERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.\n",
            "google-generativeai 0.8.4 requires google-ai-generativelanguage==0.6.15, but you have google-ai-generativelanguage 0.6.17 which is incompatible.\u001b[0m\u001b[31m\n",
            "\u001b[0mRun the following code to start the chatbot:\n",
            "create_ui()\n"
          ]
        }
      ],
      "source": [
        "# Wikipedia Chatbot with Gemini LLM using LangChain\n",
        "# This notebook creates a chatbot that answers queries using Wikipedia data\n",
        "# First uninstall the conflicting packages\n",
        "!pip uninstall -y google-generativeai google-ai-generativelanguage\n",
        "\n",
        "# Then install the compatible versions\n",
        "!pip install -q google-ai-generativelanguage==0.6.15\n",
        "!pip install -q google-generativeai==0.8.4\n",
        "\n",
        "# Now install the rest of the requirements\n",
        "!pip install -q langchain langchain-google-genai faiss-cpu wikipedia-api sentence-transformers\n",
        "# Install necessary packages\n",
        "!pip install -q langchain langchain-google-genai faiss-cpu wikipedia-api sentence-transformers\n",
        "\n",
        "# Import required libraries\n",
        "import os\n",
        "import wikipedia\n",
        "import google.generativeai as genai\n",
        "from langchain.vectorstores import FAISS\n",
        "from langchain.embeddings import HuggingFaceEmbeddings\n",
        "from langchain.text_splitter import RecursiveCharacterTextSplitter\n",
        "from langchain_google_genai import GoogleGenerativeAIEmbeddings, ChatGoogleGenerativeAI\n",
        "from langchain.chains import ConversationalRetrievalChain\n",
        "from langchain.memory import ConversationBufferMemory\n",
        "from IPython.display import display, Markdown\n",
        "import warnings\n",
        "warnings.filterwarnings('ignore')\n",
        "\n",
        "# Set up Google API key\n",
        "# You'll need to get an API key from https://makersuite.google.com/app/apikey\n",
        "GOOGLE_API_KEY = \"AIzaSyCW5HzSyVUTqh7VbS6nFUiJsoo2fKSjbwM\"  # Replace with your actual API key\n",
        "os.environ[\"GOOGLE_API_KEY\"] = GOOGLE_API_KEY\n",
        "genai.configure(api_key=GOOGLE_API_KEY)\n",
        "\n",
        "# Function to fetch Wikipedia data for a given topic\n",
        "def fetch_wikipedia_content(query, num_results=3):\n",
        "    print(f\"Searching Wikipedia for: {query}\")\n",
        "\n",
        "    # Search for Wikipedia pages related to the query\n",
        "    search_results = wikipedia.search(query, results=num_results)\n",
        "\n",
        "    if not search_results:\n",
        "        return \"No Wikipedia results found for the query.\"\n",
        "\n",
        "    all_content = \"\"\n",
        "\n",
        "    # For each search result, try to get the page content\n",
        "    for title in search_results:\n",
        "        try:\n",
        "            # Get the Wikipedia page\n",
        "            page = wikipedia.page(title, auto_suggest=False)\n",
        "\n",
        "            # Add page title and content to our collection\n",
        "            all_content += f\"Title: {page.title}\\n\\nContent:\\n{page.content}\\n\\n\"\n",
        "            print(f\"Added content from: {page.title}\")\n",
        "        except Exception as e:\n",
        "            print(f\"Error fetching {title}: {str(e)}\")\n",
        "            continue\n",
        "\n",
        "    return all_content\n",
        "\n",
        "# Create embeddings using Sentence Transformers (alternative to GoogleGenerativeAIEmbeddings)\n",
        "def create_vector_db(text_chunks):\n",
        "    embeddings = HuggingFaceEmbeddings(\n",
        "        model_name=\"all-MiniLM-L6-v2\",\n",
        "        model_kwargs={'device': 'cpu'}\n",
        "    )\n",
        "\n",
        "    # Create the FAISS vector store\n",
        "    vector_store = FAISS.from_texts(texts=text_chunks, embedding=embeddings)\n",
        "    return vector_store\n",
        "\n",
        "# Text splitter function\n",
        "def split_text(text):\n",
        "    text_splitter = RecursiveCharacterTextSplitter(\n",
        "        chunk_size=1000,\n",
        "        chunk_overlap=200,\n",
        "        length_function=len\n",
        "    )\n",
        "    chunks = text_splitter.split_text(text)\n",
        "    return chunks\n",
        "\n",
        "# Set up the Gemini LLM\n",
        "def setup_gemini_llm():\n",
        "    llm = ChatGoogleGenerativeAI(\n",
        "        model=\"gemini-1.5-pro\",\n",
        "        temperature=0.2,\n",
        "        top_p=0.85,\n",
        "        top_k=40,\n",
        "        max_output_tokens=2048,\n",
        "        verbose=True\n",
        "    )\n",
        "    return llm\n",
        "\n",
        "# Create a Wikipedia chatbot\n",
        "def create_wikipedia_chatbot(topic):\n",
        "    # 1. Fetch Wikipedia content\n",
        "    wiki_content = fetch_wikipedia_content(topic)\n",
        "\n",
        "    # 2. Split the content into chunks\n",
        "    text_chunks = split_text(wiki_content)\n",
        "    print(f\"Created {len(text_chunks)} text chunks\")\n",
        "\n",
        "    # 3. Create vector store\n",
        "    vector_store = create_vector_db(text_chunks)\n",
        "    print(\"Created FAISS vector store\")\n",
        "\n",
        "    # 4. Set up Gemini LLM\n",
        "    llm = setup_gemini_llm()\n",
        "\n",
        "    # 5. Set up conversation memory\n",
        "    memory = ConversationBufferMemory(\n",
        "        memory_key=\"chat_history\",\n",
        "        return_messages=True\n",
        "    )\n",
        "\n",
        "    # 6. Create conversational chain\n",
        "    conversation_chain = ConversationalRetrievalChain.from_llm(\n",
        "        llm=llm,\n",
        "        retriever=vector_store.as_retriever(search_kwargs={\"k\": 4}),\n",
        "        memory=memory,\n",
        "        return_source_documents=True\n",
        "    )\n",
        "\n",
        "    return conversation_chain\n",
        "\n",
        "# Function to interact with the chatbot\n",
        "def chat_with_wikipedia(conversation_chain, query):\n",
        "    response = conversation_chain({\"question\": query})\n",
        "    answer = response[\"answer\"]\n",
        "\n",
        "    # Print source documents if available\n",
        "    if \"source_documents\" in response:\n",
        "        sources = response.get(\"source_documents\", [])\n",
        "        if sources:\n",
        "            sources_text = \"\\n\\nReferences:\"\n",
        "            for i, doc in enumerate(sources, 1):\n",
        "                sources_text += f\"\\n{i}. Content chunk from Wikipedia\"\n",
        "            answer += sources_text\n",
        "\n",
        "    return answer\n",
        "\n",
        "# Demo: Create a chatbot for a specific topic\n",
        "def run_wikipedia_chatbot(initial_topic=\"Artificial Intelligence\"):\n",
        "    print(f\"Initializing Wikipedia chatbot with topic: {initial_topic}\")\n",
        "    conversation_chain = create_wikipedia_chatbot(initial_topic)\n",
        "\n",
        "    print(\"\\n\" + \"=\"*50)\n",
        "    print(\"Wikipedia Chatbot is ready! Ask questions about the topic.\")\n",
        "    print(\"Type 'new topic: [your topic]' to change the topic.\")\n",
        "    print(\"Type 'exit' to end the conversation.\")\n",
        "    print(\"=\"*50 + \"\\n\")\n",
        "\n",
        "    while True:\n",
        "        user_input = input(\"Your question: \")\n",
        "\n",
        "        if user_input.lower() == 'exit':\n",
        "            print(\"Goodbye!\")\n",
        "            break\n",
        "\n",
        "        # Check if user wants to change the topic\n",
        "        if user_input.lower().startswith(\"new topic:\"):\n",
        "            new_topic = user_input[len(\"new topic:\"):].strip()\n",
        "            print(f\"\\nChanging topic to: {new_topic}\")\n",
        "            conversation_chain = create_wikipedia_chatbot(new_topic)\n",
        "            print(\"Topic changed successfully! Ask a question about the new topic.\\n\")\n",
        "            continue\n",
        "\n",
        "        # Get response from the chatbot\n",
        "        response = chat_with_wikipedia(conversation_chain, user_input)\n",
        "\n",
        "        # Display the response\n",
        "        display(Markdown(response))\n",
        "        print(\"\\n\" + \"-\"*50 + \"\\n\")\n",
        "\n",
        "# Run the chatbot - uncomment to run directly\n",
        "# run_wikipedia_chatbot(\"Quantum Computing\")\n",
        "\n",
        "# Interactive UI with user input (better for Google Colab)\n",
        "from IPython.display import HTML, display\n",
        "import ipywidgets as widgets\n",
        "\n",
        "def create_ui():\n",
        "    # Initialize with AI topic\n",
        "    conversation_chain = create_wikipedia_chatbot(\"Artificial Intelligence\")\n",
        "\n",
        "    # Create output area\n",
        "    output = widgets.Output()\n",
        "\n",
        "    # Create text input\n",
        "    text_input = widgets.Text(\n",
        "        value='',\n",
        "        placeholder='Type your question or \"new topic: [topic]\" to change topics',\n",
        "        description='',\n",
        "        layout=widgets.Layout(width='80%')\n",
        "    )\n",
        "\n",
        "    # Create send button\n",
        "    send_button = widgets.Button(\n",
        "        description='Send',\n",
        "        button_style='primary',\n",
        "        layout=widgets.Layout(width='19%')\n",
        "    )\n",
        "\n",
        "    # Create input area\n",
        "    input_area = widgets.HBox([text_input, send_button])\n",
        "\n",
        "    # Display widgets\n",
        "    display(widgets.VBox([output, input_area]))\n",
        "\n",
        "    with output:\n",
        "        display(Markdown(\"# Wikipedia Chatbot with Gemini\\n\\n**Current topic:** Artificial Intelligence\\n\\nAsk questions or type 'new topic: [your topic]' to change topics\"))\n",
        "\n",
        "    def on_button_click(b):\n",
        "        query = text_input.value\n",
        "        text_input.value = ''\n",
        "\n",
        "        with output:\n",
        "            display(Markdown(f\"**You:** {query}\"))\n",
        "\n",
        "            if query.lower().startswith(\"new topic:\"):\n",
        "                new_topic = query[len(\"new topic:\"):].strip()\n",
        "                display(Markdown(f\"*Changing topic to: {new_topic}...*\"))\n",
        "                nonlocal conversation_chain\n",
        "                conversation_chain = create_wikipedia_chatbot(new_topic)\n",
        "                display(Markdown(f\"**Topic changed to:** {new_topic}\"))\n",
        "            else:\n",
        "                display(Markdown(\"*Thinking...*\"))\n",
        "                try:\n",
        "                    response = chat_with_wikipedia(conversation_chain, query)\n",
        "                    display(Markdown(f\"**Wikipedia Bot:** {response}\"))\n",
        "                except Exception as e:\n",
        "                    display(Markdown(f\"**Error:** {str(e)}\"))\n",
        "\n",
        "            display(Markdown(\"---\"))\n",
        "\n",
        "    send_button.on_click(on_button_click)\n",
        "\n",
        "    def on_enter(sender):\n",
        "        on_button_click(None)\n",
        "\n",
        "    text_input.on_submit(on_enter)\n",
        "\n",
        "# Uncomment to run the interactive UI\n",
        "# create_ui()\n",
        "\n",
        "# Example usage in Colab\n",
        "print(\"Run the following code to start the chatbot:\")\n",
        "print(\"create_ui()\")"
      ]
    },
    {
      "cell_type": "markdown",
      "metadata": {
        "id": "uS6y1icTyf_4"
      },
      "source": [
        "# Wikipedia Chatbot with Gemini LLM using LangChain\n",
        "# This notebook creates a chatbot that answers queries using Wikipedia data\n",
        "\n",
        "# Install necessary packages with fixed versions\n",
        "!pip uninstall -y google-generativeai google-ai-generativelanguage langchain-google-genai\n",
        "!pip install -q google-ai-generativelanguage==0.6.15\n",
        "!pip install -q google-generativeai==0.8.4\n",
        "!pip install -q langchain-google-genai==0.0.9\n",
        "!pip install -q langchain faiss-cpu wikipedia-api sentence-transformers\n",
        "\n",
        "# Import required libraries\n",
        "import os\n",
        "import wikipedia\n",
        "import google.generativeai as genai\n",
        "from langchain.vectorstores import FAISS\n",
        "from langchain.embeddings import HuggingFaceEmbeddings\n",
        "from langchain.text_splitter import RecursiveCharacterTextSplitter\n",
        "from langchain_google_genai import ChatGoogleGenerativeAI\n",
        "from langchain.chains import ConversationalRetrievalChain\n",
        "from langchain.memory import ConversationBufferMemory\n",
        "from IPython.display import display, Markdown\n",
        "import warnings\n",
        "warnings.filterwarnings('ignore')\n",
        "\n",
        "# Set up Google API key\n",
        "# You'll need to get an API key from https://makersuite.google.com/app/apikey\n",
        "GOOGLE_API_KEY = \"your_google_api_key_here\"  # Replace with your actual API key\n",
        "os.environ[\"GOOGLE_API_KEY\"] = GOOGLE_API_KEY\n",
        "genai.configure(api_key=GOOGLE_API_KEY)\n",
        "\n",
        "# Function to fetch Wikipedia data for a given topic\n",
        "def fetch_wikipedia_content(query, num_results=3):\n",
        "    print(f\"Searching Wikipedia for: {query}\")\n",
        "    \n",
        "    # Search for Wikipedia pages related to the query\n",
        "    search_results = wikipedia.search(query, results=num_results)\n",
        "    \n",
        "    if not search_results:\n",
        "        return \"No Wikipedia results found for the query.\"\n",
        "    \n",
        "    all_content = \"\"\n",
        "    \n",
        "    # For each search result, try to get the page content\n",
        "    for title in search_results:\n",
        "        try:\n",
        "            # Get the Wikipedia page\n",
        "            page = wikipedia.page(title, auto_suggest=False)\n",
        "            \n",
        "            # Add page title and content to our collection\n",
        "            all_content += f\"Title: {page.title}\\n\\nContent:\\n{page.content}\\n\\n\"\n",
        "            print(f\"Added content from: {page.title}\")\n",
        "        except Exception as e:\n",
        "            print(f\"Error fetching {title}: {str(e)}\")\n",
        "            continue\n",
        "    \n",
        "    return all_content\n",
        "\n",
        "# Create embeddings using Sentence Transformers\n",
        "def create_vector_db(text_chunks):\n",
        "    embeddings = HuggingFaceEmbeddings(\n",
        "        model_name=\"all-MiniLM-L6-v2\",\n",
        "        model_kwargs={'device': 'cpu'}\n",
        "    )\n",
        "    \n",
        "    # Create the FAISS vector store\n",
        "    vector_store = FAISS.from_texts(texts=text_chunks, embedding=embeddings)\n",
        "    return vector_store\n",
        "\n",
        "# Text splitter function\n",
        "def split_text(text):\n",
        "    text_splitter = RecursiveCharacterTextSplitter(\n",
        "        chunk_size=1000,\n",
        "        chunk_overlap=200,\n",
        "        length_function=len\n",
        "    )\n",
        "    chunks = text_splitter.split_text(text)\n",
        "    return chunks\n",
        "\n",
        "# Set up the Gemini LLM\n",
        "def setup_gemini_llm():\n",
        "    # Updated to match the older langchain-google-genai version's API\n",
        "    llm = ChatGoogleGenerativeAI(\n",
        "        model=\"gemini-pro\",\n",
        "        temperature=0.2,\n",
        "    )\n",
        "    return llm\n",
        "\n",
        "# Create a Wikipedia chatbot\n",
        "def create_wikipedia_chatbot(topic):\n",
        "    # 1. Fetch Wikipedia content\n",
        "    wiki_content = fetch_wikipedia_content(topic)\n",
        "    \n",
        "    # 2. Split the content into chunks\n",
        "    text_chunks = split_text(wiki_content)\n",
        "    print(f\"Created {len(text_chunks)} text chunks\")\n",
        "    \n",
        "    # 3. Create vector store\n",
        "    vector_store = create_vector_db(text_chunks)\n",
        "    print(\"Created FAISS vector store\")\n",
        "    \n",
        "    # 4. Set up Gemini LLM\n",
        "    llm = setup_gemini_llm()\n",
        "    \n",
        "    # 5. Set up conversation memory\n",
        "    memory = ConversationBufferMemory(\n",
        "        memory_key=\"chat_history\",\n",
        "        return_messages=True\n",
        "    )\n",
        "    \n",
        "    # 6. Create conversational chain\n",
        "    conversation_chain = ConversationalRetrievalChain.from_llm(\n",
        "        llm=llm,\n",
        "        retriever=vector_store.as_retriever(search_kwargs={\"k\": 4}),\n",
        "        memory=memory,\n",
        "        return_source_documents=True\n",
        "    )\n",
        "    \n",
        "    return conversation_chain\n",
        "\n",
        "# Function to interact with the chatbot\n",
        "def chat_with_wikipedia(conversation_chain, query):\n",
        "    response = conversation_chain({\"question\": query})\n",
        "    answer = response[\"answer\"]\n",
        "    \n",
        "    # Print source documents if available\n",
        "    if \"source_documents\" in response:\n",
        "        sources = response.get(\"source_documents\", [])\n",
        "        if sources:\n",
        "            sources_text = \"\\n\\nReferences:\"\n",
        "            for i, doc in enumerate(sources, 1):\n",
        "                sources_text += f\"\\n{i}. Content chunk from Wikipedia\"\n",
        "            answer += sources_text\n",
        "    \n",
        "    return answer\n",
        "\n",
        "# Demo: Create a chatbot for a specific topic\n",
        "def run_wikipedia_chatbot(initial_topic=\"Artificial Intelligence\"):\n",
        "    print(f\"Initializing Wikipedia chatbot with topic: {initial_topic}\")\n",
        "    conversation_chain = create_wikipedia_chatbot(initial_topic)\n",
        "    \n",
        "    print(\"\\n\" + \"=\"*50)\n",
        "    print(\"Wikipedia Chatbot is ready! Ask questions about the topic.\")\n",
        "    print(\"Type 'new topic: [your topic]' to change the topic.\")\n",
        "    print(\"Type 'exit' to end the conversation.\")\n",
        "    print(\"=\"*50 + \"\\n\")\n",
        "    \n",
        "    while True:\n",
        "        user_input = input(\"Your question: \")\n",
        "        \n",
        "        if user_input.lower() == 'exit':\n",
        "            print(\"Goodbye!\")\n",
        "            break\n",
        "        \n",
        "        # Check if user wants to change the topic\n",
        "        if user_input.lower().startswith(\"new topic:\"):\n",
        "            new_topic = user_input[len(\"new topic:\"):].strip()\n",
        "            print(f\"\\nChanging topic to: {new_topic}\")\n",
        "            conversation_chain = create_wikipedia_chatbot(new_topic)\n",
        "            print(\"Topic changed successfully! Ask a question about the new topic.\\n\")\n",
        "            continue\n",
        "        \n",
        "        # Get response from the chatbot\n",
        "        response = chat_with_wikipedia(conversation_chain, user_input)\n",
        "        \n",
        "        # Display the response\n",
        "        display(Markdown(response))\n",
        "        print(\"\\n\" + \"-\"*50 + \"\\n\")\n",
        "\n",
        "# Interactive UI with user input (for Google Colab)\n",
        "from IPython.display import HTML, display\n",
        "import ipywidgets as widgets\n",
        "\n",
        "def create_ui():\n",
        "    # Initialize with AI topic\n",
        "    conversation_chain = create_wikipedia_chatbot(\"Artificial Intelligence\")\n",
        "    \n",
        "    # Create output area\n",
        "    output = widgets.Output()\n",
        "    \n",
        "    # Create text input\n",
        "    text_input = widgets.Text(\n",
        "        value='',\n",
        "        placeholder='Type your question or \"new topic: [topic]\" to change topics',\n",
        "        description='',\n",
        "        layout=widgets.Layout(width='80%')\n",
        "    )\n",
        "    \n",
        "    # Create send button\n",
        "    send_button = widgets.Button(\n",
        "        description='Send',\n",
        "        button_style='primary',\n",
        "        layout=widgets.Layout(width='19%')\n",
        "    )\n",
        "    \n",
        "    # Create input area\n",
        "    input_area = widgets.HBox([text_input, send_button])\n",
        "    \n",
        "    # Display widgets\n",
        "    display(widgets.VBox([output, input_area]))\n",
        "    \n",
        "    with output:\n",
        "        display(Markdown(\"# Wikipedia Chatbot with Gemini\\n\\n**Current topic:** Artificial Intelligence\\n\\nAsk questions or type 'new topic: [your topic]' to change topics\"))\n",
        "    \n",
        "    def on_button_click(b):\n",
        "        query = text_input.value\n",
        "        text_input.value = ''\n",
        "        \n",
        "        with output:\n",
        "            display(Markdown(f\"**You:** {query}\"))\n",
        "            \n",
        "            if query.lower().startswith(\"new topic:\"):\n",
        "                new_topic = query[len(\"new topic:\"):].strip()\n",
        "                display(Markdown(f\"*Changing topic to: {new_topic}...*\"))\n",
        "                nonlocal conversation_chain\n",
        "                conversation_chain = create_wikipedia_chatbot(new_topic)\n",
        "                display(Markdown(f\"**Topic changed to:** {new_topic}\"))\n",
        "            else:\n",
        "                display(Markdown(\"*Thinking...*\"))\n",
        "                try:\n",
        "                    response = chat_with_wikipedia(conversation_chain, query)\n",
        "                    display(Markdown(f\"**Wikipedia Bot:** {response}\"))\n",
        "                except Exception as e:\n",
        "                    display(Markdown(f\"**Error:** {str(e)}\"))\n",
        "            \n",
        "            display(Markdown(\"---\"))\n",
        "    \n",
        "    send_button.on_click(on_button_click)\n",
        "    \n",
        "    def on_enter(sender):\n",
        "        on_button_click(None)\n",
        "    \n",
        "    text_input.on_submit(on_enter)\n",
        "\n",
        "# Example usage in Colab\n",
        "print(\"Run the following code to start the chatbot:\")\n",
        "print(\"create_ui()\")"
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "QKiNWHM3yuqW",
        "outputId": "3bdbd39f-105a-4f28-fde2-4c8dab0bc6f2"
      },
      "outputs": [
        {
          "name": "stdout",
          "output_type": "stream",
          "text": [
            "Found existing installation: google-generativeai 0.8.4\n",
            "Uninstalling google-generativeai-0.8.4:\n",
            "  Successfully uninstalled google-generativeai-0.8.4\n",
            "Found existing installation: google-ai-generativelanguage 0.6.17\n",
            "Uninstalling google-ai-generativelanguage-0.6.17:\n",
            "  Successfully uninstalled google-ai-generativelanguage-0.6.17\n",
            "Found existing installation: langchain-google-genai 2.1.2\n",
            "Uninstalling langchain-google-genai-2.1.2:\n",
            "  Successfully uninstalled langchain-google-genai-2.1.2\n",
            "\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m146.9/146.9 kB\u001b[0m \u001b[31m3.8 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
            "\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m598.7/598.7 kB\u001b[0m \u001b[31m16.0 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
            "\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m303.1/303.1 kB\u001b[0m \u001b[31m16.9 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
            "\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m311.8/311.8 kB\u001b[0m \u001b[31m18.6 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
            "\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m53.0/53.0 kB\u001b[0m \u001b[31m3.4 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
            "\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m294.6/294.6 kB\u001b[0m \u001b[31m16.6 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
            "\u001b[?25h\u001b[31mERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.\n",
            "langchain-community 0.3.21 requires langchain-core<1.0.0,>=0.3.51, but you have langchain-core 0.1.53 which is incompatible.\n",
            "langchain-text-splitters 0.3.8 requires langchain-core<1.0.0,>=0.3.51, but you have langchain-core 0.1.53 which is incompatible.\n",
            "langchain 0.3.23 requires langchain-core<1.0.0,>=0.3.51, but you have langchain-core 0.1.53 which is incompatible.\n",
            "google-cloud-bigquery 3.31.0 requires packaging>=24.2.0, but you have packaging 23.2 which is incompatible.\u001b[0m\u001b[31m\n",
            "\u001b[0m\u001b[31mERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.\n",
            "langchain-google-genai 0.0.9 requires langchain-core<0.2,>=0.1, but you have langchain-core 0.3.51 which is incompatible.\u001b[0m\u001b[31m\n",
            "\u001b[0mRun the following code to start the chatbot:\n",
            "create_ui()\n"
          ]
        }
      ],
      "source": [
        "# Wikipedia Chatbot with Gemini LLM using LangChain\n",
        "# This notebook creates a chatbot that answers queries using Wikipedia data\n",
        "\n",
        "# Install necessary packages with fixed versions\n",
        "!pip uninstall -y google-generativeai google-ai-generativelanguage langchain-google-genai\n",
        "!pip install -q google-ai-generativelanguage==0.6.15\n",
        "!pip install -q google-generativeai==0.8.4\n",
        "!pip install -q langchain-google-genai==0.0.9\n",
        "!pip install -q langchain faiss-cpu wikipedia-api sentence-transformers\n",
        "\n",
        "# Import required libraries\n",
        "import os\n",
        "import wikipedia\n",
        "import google.generativeai as genai\n",
        "from langchain.vectorstores import FAISS\n",
        "from langchain.embeddings import HuggingFaceEmbeddings\n",
        "from langchain.text_splitter import RecursiveCharacterTextSplitter\n",
        "from langchain_google_genai import ChatGoogleGenerativeAI\n",
        "from langchain.chains import ConversationalRetrievalChain\n",
        "from langchain.memory import ConversationBufferMemory\n",
        "from IPython.display import display, Markdown\n",
        "import warnings\n",
        "warnings.filterwarnings('ignore')\n",
        "\n",
        "# Set up Google API key\n",
        "# You'll need to get an API key from https://makersuite.google.com/app/apikey\n",
        "GOOGLE_API_KEY = \"AIzaSyCW5HzSyVUTqh7VbS6nFUiJsoo2fKSjbwM\"  # Replace with your actual API key\n",
        "os.environ[\"GOOGLE_API_KEY\"] = GOOGLE_API_KEY\n",
        "genai.configure(api_key=GOOGLE_API_KEY)\n",
        "\n",
        "# Function to fetch Wikipedia data for a given topic\n",
        "def fetch_wikipedia_content(query, num_results=3):\n",
        "    print(f\"Searching Wikipedia for: {query}\")\n",
        "\n",
        "    # Search for Wikipedia pages related to the query\n",
        "    search_results = wikipedia.search(query, results=num_results)\n",
        "\n",
        "    if not search_results:\n",
        "        return \"No Wikipedia results found for the query.\"\n",
        "\n",
        "    all_content = \"\"\n",
        "\n",
        "    # For each search result, try to get the page content\n",
        "    for title in search_results:\n",
        "        try:\n",
        "            # Get the Wikipedia page\n",
        "            page = wikipedia.page(title, auto_suggest=False)\n",
        "\n",
        "            # Add page title and content to our collection\n",
        "            all_content += f\"Title: {page.title}\\n\\nContent:\\n{page.content}\\n\\n\"\n",
        "            print(f\"Added content from: {page.title}\")\n",
        "        except Exception as e:\n",
        "            print(f\"Error fetching {title}: {str(e)}\")\n",
        "            continue\n",
        "\n",
        "    return all_content\n",
        "\n",
        "# Create embeddings using Sentence Transformers\n",
        "def create_vector_db(text_chunks):\n",
        "    embeddings = HuggingFaceEmbeddings(\n",
        "        model_name=\"all-MiniLM-L6-v2\",\n",
        "        model_kwargs={'device': 'cpu'}\n",
        "    )\n",
        "\n",
        "    # Create the FAISS vector store\n",
        "    vector_store = FAISS.from_texts(texts=text_chunks, embedding=embeddings)\n",
        "    return vector_store\n",
        "\n",
        "# Text splitter function\n",
        "def split_text(text):\n",
        "    text_splitter = RecursiveCharacterTextSplitter(\n",
        "        chunk_size=1000,\n",
        "        chunk_overlap=200,\n",
        "        length_function=len\n",
        "    )\n",
        "    chunks = text_splitter.split_text(text)\n",
        "    return chunks\n",
        "\n",
        "# Set up the Gemini LLM\n",
        "def setup_gemini_llm():\n",
        "    # Updated to match the older langchain-google-genai version's API\n",
        "    llm = ChatGoogleGenerativeAI(\n",
        "        model=\"gemini-1.5-pro\",\n",
        "        temperature=0.2,\n",
        "    )\n",
        "    return llm\n",
        "\n",
        "# Create a Wikipedia chatbot\n",
        "def create_wikipedia_chatbot(topic):\n",
        "    # 1. Fetch Wikipedia content\n",
        "    wiki_content = fetch_wikipedia_content(topic)\n",
        "\n",
        "    # 2. Split the content into chunks\n",
        "    text_chunks = split_text(wiki_content)\n",
        "    print(f\"Created {len(text_chunks)} text chunks\")\n",
        "\n",
        "    # 3. Create vector store\n",
        "    vector_store = create_vector_db(text_chunks)\n",
        "    print(\"Created FAISS vector store\")\n",
        "\n",
        "    # 4. Set up Gemini LLM\n",
        "    llm = setup_gemini_llm()\n",
        "\n",
        "    # 5. Set up conversation memory\n",
        "    memory = ConversationBufferMemory(\n",
        "        memory_key=\"chat_history\",\n",
        "        return_messages=True\n",
        "    )\n",
        "\n",
        "    # 6. Create conversational chain\n",
        "    conversation_chain = ConversationalRetrievalChain.from_llm(\n",
        "        llm=llm,\n",
        "        retriever=vector_store.as_retriever(search_kwargs={\"k\": 4}),\n",
        "        memory=memory,\n",
        "        return_source_documents=True\n",
        "    )\n",
        "\n",
        "    return conversation_chain\n",
        "\n",
        "# Function to interact with the chatbot\n",
        "def chat_with_wikipedia(conversation_chain, query):\n",
        "    response = conversation_chain({\"question\": query})\n",
        "    answer = response[\"answer\"]\n",
        "\n",
        "    # Print source documents if available\n",
        "    if \"source_documents\" in response:\n",
        "        sources = response.get(\"source_documents\", [])\n",
        "        if sources:\n",
        "            sources_text = \"\\n\\nReferences:\"\n",
        "            for i, doc in enumerate(sources, 1):\n",
        "                sources_text += f\"\\n{i}. Content chunk from Wikipedia\"\n",
        "            answer += sources_text\n",
        "\n",
        "    return answer\n",
        "\n",
        "# Demo: Create a chatbot for a specific topic\n",
        "def run_wikipedia_chatbot(initial_topic=\"Artificial Intelligence\"):\n",
        "    print(f\"Initializing Wikipedia chatbot with topic: {initial_topic}\")\n",
        "    conversation_chain = create_wikipedia_chatbot(initial_topic)\n",
        "\n",
        "    print(\"\\n\" + \"=\"*50)\n",
        "    print(\"Wikipedia Chatbot is ready! Ask questions about the topic.\")\n",
        "    print(\"Type 'new topic: [your topic]' to change the topic.\")\n",
        "    print(\"Type 'exit' to end the conversation.\")\n",
        "    print(\"=\"*50 + \"\\n\")\n",
        "\n",
        "    while True:\n",
        "        user_input = input(\"Your question: \")\n",
        "\n",
        "        if user_input.lower() == 'exit':\n",
        "            print(\"Goodbye!\")\n",
        "            break\n",
        "\n",
        "        # Check if user wants to change the topic\n",
        "        if user_input.lower().startswith(\"new topic:\"):\n",
        "            new_topic = user_input[len(\"new topic:\"):].strip()\n",
        "            print(f\"\\nChanging topic to: {new_topic}\")\n",
        "            conversation_chain = create_wikipedia_chatbot(new_topic)\n",
        "            print(\"Topic changed successfully! Ask a question about the new topic.\\n\")\n",
        "            continue\n",
        "\n",
        "        # Get response from the chatbot\n",
        "        response = chat_with_wikipedia(conversation_chain, user_input)\n",
        "\n",
        "        # Display the response\n",
        "        display(Markdown(response))\n",
        "        print(\"\\n\" + \"-\"*50 + \"\\n\")\n",
        "\n",
        "# Interactive UI with user input (for Google Colab)\n",
        "from IPython.display import HTML, display\n",
        "import ipywidgets as widgets\n",
        "\n",
        "def create_ui():\n",
        "    # Initialize with AI topic\n",
        "    conversation_chain = create_wikipedia_chatbot(\"Artificial Intelligence\")\n",
        "\n",
        "    # Create output area\n",
        "    output = widgets.Output()\n",
        "\n",
        "    # Create text input\n",
        "    text_input = widgets.Text(\n",
        "        value='',\n",
        "        placeholder='Type your question or \"new topic: [topic]\" to change topics',\n",
        "        description='',\n",
        "        layout=widgets.Layout(width='80%')\n",
        "    )\n",
        "\n",
        "    # Create send button\n",
        "    send_button = widgets.Button(\n",
        "        description='Send',\n",
        "        button_style='primary',\n",
        "        layout=widgets.Layout(width='19%')\n",
        "    )\n",
        "\n",
        "    # Create input area\n",
        "    input_area = widgets.HBox([text_input, send_button])\n",
        "\n",
        "    # Display widgets\n",
        "    display(widgets.VBox([output, input_area]))\n",
        "\n",
        "    with output:\n",
        "        display(Markdown(\"# Wikipedia Chatbot with Gemini\\n\\n**Current topic:** Artificial Intelligence\\n\\nAsk questions or type 'new topic: [your topic]' to change topics\"))\n",
        "\n",
        "    def on_button_click(b):\n",
        "        query = text_input.value\n",
        "        text_input.value = ''\n",
        "\n",
        "        with output:\n",
        "            display(Markdown(f\"**You:** {query}\"))\n",
        "\n",
        "            if query.lower().startswith(\"new topic:\"):\n",
        "                new_topic = query[len(\"new topic:\"):].strip()\n",
        "                display(Markdown(f\"*Changing topic to: {new_topic}...*\"))\n",
        "                nonlocal conversation_chain\n",
        "                conversation_chain = create_wikipedia_chatbot(new_topic)\n",
        "                display(Markdown(f\"**Topic changed to:** {new_topic}\"))\n",
        "            else:\n",
        "                display(Markdown(\"*Thinking...*\"))\n",
        "                try:\n",
        "                    response = chat_with_wikipedia(conversation_chain, query)\n",
        "                    display(Markdown(f\"**Wikipedia Bot:** {response}\"))\n",
        "                except Exception as e:\n",
        "                    display(Markdown(f\"**Error:** {str(e)}\"))\n",
        "\n",
        "            display(Markdown(\"---\"))\n",
        "\n",
        "    send_button.on_click(on_button_click)\n",
        "\n",
        "    def on_enter(sender):\n",
        "        on_button_click(None)\n",
        "\n",
        "    text_input.on_submit(on_enter)\n",
        "\n",
        "# Example usage in Colab\n",
        "print(\"Run the following code to start the chatbot:\")\n",
        "print(\"create_ui()\")"
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "metadata": {
        "colab": {
          "background_save": true,
          "base_uri": "https://localhost:8080/",
          "height": 624,
          "referenced_widgets": [
            "6aaa2712dd024a2cad13590831134a96",
            "178ae49394a34ce4a4d5ca83bbd8d202",
            "b5c2345a00704ae1bf36515aefbb23e4",
            "eda17cfb045f4e7dad91508d3719705b",
            "7a332637135341b4adb6fa72d22f1aa4",
            "0a638b778fe143a68f203b4db5d96d62",
            "8bbd731e3b5749ff946d52e915413fe6",
            "75c46b3d009f4f3780488a23b6b2361a",
            "f6e22ce791794c82950afac6768294ed",
            "4cd5eb592095405ca7699f856851b4b0",
            "cbedc2e4f79d47669ac0837949dc621f",
            "3abc55d93e334c5493b3370dbbe8c61a",
            "8e35498030ff4c8ebd3a9693066571c1",
            "5e91b8638d9d466aa97097751e8a7ba4",
            "7424b178e5b34aa9ba2c83c5d32d7db0",
            "0bd966507e234304a766730adda79c92",
            "b30224161bd84ba98bf75614a6bf0900",
            "515efe88993c421685cbea34fe223cc6",
            "aa56f547c0084046be6fc1e8cd4601c0",
            "2825de0b28b14f5a89d14983ad39b040",
            "bc9ee5cecdb34bb1bfe4789f5283765a",
            "1682424cce2e495cbbad35409c3fcac1",
            "f5a584e3002d47e19d80e9a317fd4799",
            "e9303a5d5aa34009bb23037ba3398c5c",
            "e165e11668ed45deaacf4d221e0b77c7",
            "0d7980c7cd7e4ceba45c33bdbfc524e3",
            "4473ee3c69da48b6958a5a218ab07b7e",
            "ebb6c3fa5b7f4335993729fb568d193e",
            "4efb2f3c80ad4fcdb11cd2dc0db22d5e",
            "ae977b29022c40b4bb2fdeb5bc111b1c",
            "66f9cbbc9b014e8a883f34174d5e6bb2",
            "75a631a3ad094bfd864179ba6c43aecb",
            "9c6dc2c9475748f48ff43308b550adff",
            "1eda352518b5449b97b50212e9d65d2c",
            "b2f39f1bc02b4c4c8631d99fa2019bae",
            "c903f49bd9e144dfb5704215cc11bb4d",
            "2a389830aa2647d0a0d761b19376da63",
            "9a5d4b973389432186c8f99d6678abbe",
            "9cc83daeb1ad4ebca5fe8f08fb26e7b2",
            "c8f65254038d497cb00b998ed7066dac",
            "4e3c317e3da5466a9097343018f16f26",
            "a37136f00023409cbd5c2a575af2460b",
            "9fb6952ef5a34364a6cab61021aff7b0",
            "cc5087fd30e3440c85e49973ac2e85f2",
            "ba063bf8e4fb4874923c3050d5eff5d1",
            "2d69e16ad85b4e198e1772691a64f42f",
            "236bf4b5c8ee46cf8014e5d525742a63",
            "326b46cb624647eaa22c94abd56b38d9",
            "fa56ea8e04ce43bdb971909135be3696",
            "5be0829c71dc441c96284f2d41e8233b",
            "2592edb6fbc84b64ac2311ffb0f3fd71",
            "1fb2f4e41fa241cb901c6fb0a4910408",
            "41b15b3f69e24652bc7ddb144115715f",
            "af503ca763254a55b6515fc1e4f45f42",
            "4936189f15954cf687a10afc7b471c83",
            "5c505d88f5bd4568aaf7386ec4c3c271",
            "6bbf029a90c14d53925cde8a33f0dde5",
            "bbe04bab27bf4bb8b8ba9b24b4301c34",
            "54cacaaef94d41dcbd8508cd3c341c92",
            "8b4d9831c6ac43c5a02677cfd741f927",
            "927515a2248943a9a07c498b7e1644ba",
            "6c749b4de378485898690a5fe80b9cc2",
            "2e2fd56fc4cd438ab596787a91e6a753",
            "2b48a439b6b84cc19381f04b2184c935",
            "398b746ac40c435ba7ed29323558cd9c",
            "d7e396e439cf438f9fbeac7eaa9e37c0",
            "68f42d2d023b40f29c70e3e4adc17a98",
            "10b8f12856794c69a07b1c4603ba4dd1",
            "4900f81bf89d4ff2a84c42bda673062c",
            "4ba22a69a87f49e7bddd3cb5498ab4c6",
            "03a49ad655ca47bf9ca370a015b39246",
            "36412ed310534e83baf771f95b3eb6d7",
            "3045354454cd46cd881579313730b0a6",
            "c3ff6c25b38740559eaaacb693b95432",
            "9330cdfbbbf149e1a4d11edf052cd983",
            "8b55c987ae7b4635adcdef3a006cf06e",
            "02359595fc4947d3adfb6bd1a5c22172",
            "3e03b92fe59b4c83b01ddb12e9ad90e1",
            "8a36a3ba377a40d3a15a643154d69b54",
            "26cd5e106e2844c494f79d302b32f1bd",
            "11ffad173875498490c4275f067ae339",
            "eba8c3e8a8794d22a4a40ee489a320a4",
            "2115ce2ded7443c3918ae415cf09d2d7",
            "e7264047e1d64432803c9e8d19b880f0",
            "45e6971ed75c4aea90886beb7d05248d",
            "29218c71ccb14626b506321ed67afb30",
            "1419789f9775401d81d640367cbed4d5",
            "ce35ea71bd7446308644f5aedfe5fea4",
            "d4cdfe1c32d84384a9af477ebc1487d4",
            "e2aa91ddd61643679e81f5ffaaaac496",
            "bc69ee7f189f48b3bc1fab9f2effc0fd",
            "477c348d35c345dbbe633f7d7ee3f6df",
            "6e7134ba60194823af6777d8bc32cc3a",
            "972e8c96802f4259bf9f460d804914f0",
            "cbfce47239744e8b8acb6a350825aabc",
            "198c7b289a7241bc813c5f3ade5ac1eb",
            "f81a912e5f4b42798777a7016af8da68",
            "7cf17f9a4f6a46e5b38541f7bf7306bc",
            "1430ecb388a24db3a0c41060a67643cc",
            "400719cb832e4932ab52bf5e470738a5",
            "83244d4ed46d4367b0d0a652da8e71b3",
            "9961baf94e844e58b6cb587b3bb93221",
            "c4d40455bcef430db00e8acf2aa7b93b",
            "4e82dd3ceadf43d18d4257d12ebdaa83",
            "683a808475e040b684d68c887faf07ae",
            "7c001196edf044faa9dcd88328f8dcca",
            "c0eabd24567042dd8921da7fdcfe1fa8",
            "8c9e2d3e56a444eea3133835df1d8812",
            "0b0bed92af8a4b6ca58ad836947912d8",
            "8b50a41fa52c4a2091033320e445295f",
            "24d211a7bc7742a9a985333cc33f1086",
            "85a1df7529334898977595faf103aa21",
            "297979735fd84929aee6c569951e6e57",
            "afed89d2221841119c06d392aafca362",
            "6d4d0f1a8c734d489f1b273bdc9a3fd2",
            "a17c5907f34a4830aeab94e7da23516a",
            "8da7cd7e50284e0bb8c2e4b5dc95f8e7",
            "6c369920b4674439aa5884e06cfc1d05",
            "9d5da1c6c00044ee88fdc0ca5af1d260",
            "ff9575d0cffb4cf9bcf725cb26a55a1e",
            "e990abcf62c44b17ad3c7122fe2c0cc5"
          ]
        },
        "id": "g6MLaYxYzLGJ",
        "outputId": "df369ed5-44bd-4353-b261-d6bd2a23bf73"
      },
      "outputs": [
        {
          "name": "stdout",
          "output_type": "stream",
          "text": [
            "\u001b[?25l   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m0.0/42.0 kB\u001b[0m \u001b[31m?\u001b[0m eta \u001b[36m-:--:--\u001b[0m\r\u001b[2K   \u001b[90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\u001b[0m \u001b[32m42.0/42.0 kB\u001b[0m \u001b[31m1.6 MB/s\u001b[0m eta \u001b[36m0:00:00\u001b[0m\n",
            "\u001b[?25hGetting Wikipedia information about: Quantum Computing\n",
            "Created 7 text chunks\n"
          ]
        },
        {
          "data": {
            "application/vnd.jupyter.widget-view+json": {
              "model_id": "6aaa2712dd024a2cad13590831134a96",
              "version_major": 2,
              "version_minor": 0
            },
            "text/plain": [
              "modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]"
            ]
          },
          "metadata": {},
          "output_type": "display_data"
        },
        {
          "data": {
            "application/vnd.jupyter.widget-view+json": {
              "model_id": "3abc55d93e334c5493b3370dbbe8c61a",
              "version_major": 2,
              "version_minor": 0
            },
            "text/plain": [
              "config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]"
            ]
          },
          "metadata": {},
          "output_type": "display_data"
        },
        {
          "data": {
            "application/vnd.jupyter.widget-view+json": {
              "model_id": "f5a584e3002d47e19d80e9a317fd4799",
              "version_major": 2,
              "version_minor": 0
            },
            "text/plain": [
              "README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]"
            ]
          },
          "metadata": {},
          "output_type": "display_data"
        },
        {
          "data": {
            "application/vnd.jupyter.widget-view+json": {
              "model_id": "1eda352518b5449b97b50212e9d65d2c",
              "version_major": 2,
              "version_minor": 0
            },
            "text/plain": [
              "sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]"
            ]
          },
          "metadata": {},
          "output_type": "display_data"
        },
        {
          "data": {
            "application/vnd.jupyter.widget-view+json": {
              "model_id": "ba063bf8e4fb4874923c3050d5eff5d1",
              "version_major": 2,
              "version_minor": 0
            },
            "text/plain": [
              "config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]"
            ]
          },
          "metadata": {},
          "output_type": "display_data"
        },
        {
          "name": "stderr",
          "output_type": "stream",
          "text": [
            "Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`\n",
            "WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`\n"
          ]
        },
        {
          "data": {
            "application/vnd.jupyter.widget-view+json": {
              "model_id": "5c505d88f5bd4568aaf7386ec4c3c271",
              "version_major": 2,
              "version_minor": 0
            },
            "text/plain": [
              "model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]"
            ]
          },
          "metadata": {},
          "output_type": "display_data"
        },
        {
          "data": {
            "application/vnd.jupyter.widget-view+json": {
              "model_id": "68f42d2d023b40f29c70e3e4adc17a98",
              "version_major": 2,
              "version_minor": 0
            },
            "text/plain": [
              "tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]"
            ]
          },
          "metadata": {},
          "output_type": "display_data"
        },
        {
          "data": {
            "application/vnd.jupyter.widget-view+json": {
              "model_id": "3e03b92fe59b4c83b01ddb12e9ad90e1",
              "version_major": 2,
              "version_minor": 0
            },
            "text/plain": [
              "vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]"
            ]
          },
          "metadata": {},
          "output_type": "display_data"
        },
        {
          "data": {
            "application/vnd.jupyter.widget-view+json": {
              "model_id": "d4cdfe1c32d84384a9af477ebc1487d4",
              "version_major": 2,
              "version_minor": 0
            },
            "text/plain": [
              "tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]"
            ]
          },
          "metadata": {},
          "output_type": "display_data"
        },
        {
          "data": {
            "application/vnd.jupyter.widget-view+json": {
              "model_id": "400719cb832e4932ab52bf5e470738a5",
              "version_major": 2,
              "version_minor": 0
            },
            "text/plain": [
              "special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]"
            ]
          },
          "metadata": {},
          "output_type": "display_data"
        },
        {
          "data": {
            "application/vnd.jupyter.widget-view+json": {
              "model_id": "24d211a7bc7742a9a985333cc33f1086",
              "version_major": 2,
              "version_minor": 0
            },
            "text/plain": [
              "config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]"
            ]
          },
          "metadata": {},
          "output_type": "display_data"
        },
        {
          "name": "stdout",
          "output_type": "stream",
          "text": [
            "Created FAISS vector store\n",
            "\n",
            "===== Wikipedia Chatbot is ready! =====\n",
            "Type 'new topic: [your topic]' to change topics\n",
            "Type 'exit' to quit\n",
            "\n",
            "Error: Got multiple output keys: dict_keys(['answer', 'source_documents']), cannot determine which to store in memory. Please set the 'output_key' explicitly.\n"
          ]
        }
      ],
      "source": [
        "# STEP 1: Install Required Packages\n",
        "!pip install -q langchain langchain-community langchain-google-genai google-generativeai faiss-cpu wikipedia sentence-transformers\n",
        "\n",
        "# STEP 2: Import Libraries\n",
        "import os\n",
        "import google.generativeai as genai\n",
        "from langchain_google_genai import ChatGoogleGenerativeAI\n",
        "from langchain_community.vectorstores import FAISS\n",
        "from langchain_community.embeddings import HuggingFaceEmbeddings\n",
        "from langchain_community.utilities import WikipediaAPIWrapper\n",
        "from langchain.text_splitter import RecursiveCharacterTextSplitter\n",
        "from langchain.chains import ConversationalRetrievalChain\n",
        "from langchain.memory import ConversationBufferMemory\n",
        "from langchain.schema import SystemMessage, HumanMessage\n",
        "\n",
        "# STEP 3: Set your Google API Key (replace with your actual key)\n",
        "GOOGLE_API_KEY = \"AIzaSyCW5HzSyVUTqh7VbS6nFUiJsoo2fKSjbwM\"  # Replace with your actual API key\n",
        "os.environ[\"GOOGLE_API_KEY\"] = GOOGLE_API_KEY\n",
        "genai.configure(api_key=GOOGLE_API_KEY)\n",
        "\n",
        "# STEP 4: Initialize Gemini LLM\n",
        "def get_llm():\n",
        "    return ChatGoogleGenerativeAI(\n",
        "        model=\"gemini-1.5-pro\",\n",
        "        temperature=0.2,\n",
        "    )\n",
        "\n",
        "# STEP 5: Set up Wikipedia Content Retrieval and Processing\n",
        "def get_wiki_content(query, max_results=3):\n",
        "    # Use the WikipediaAPIWrapper to get content\n",
        "    wiki = WikipediaAPIWrapper(top_k_results=max_results)\n",
        "    wiki_content = wiki.run(query)\n",
        "    return wiki_content\n",
        "\n",
        "def process_text(text):\n",
        "    # Split the text into chunks for better processing\n",
        "    text_splitter = RecursiveCharacterTextSplitter(\n",
        "        chunk_size=1000,\n",
        "        chunk_overlap=200,\n",
        "        length_function=len\n",
        "    )\n",
        "    chunks = text_splitter.split_text(text)\n",
        "    return chunks\n",
        "\n",
        "# STEP 6: Create FAISS Vector Database\n",
        "def create_vector_db(text_chunks):\n",
        "    # Use Sentence Transformers for embeddings\n",
        "    embeddings = HuggingFaceEmbeddings(\n",
        "        model_name=\"all-MiniLM-L6-v2\",\n",
        "        model_kwargs={'device': 'cpu'}\n",
        "    )\n",
        "\n",
        "    # Create FAISS vector store from text chunks\n",
        "    vector_store = FAISS.from_texts(texts=text_chunks, embedding=embeddings)\n",
        "    return vector_store\n",
        "\n",
        "# STEP 7: Create the Wikipedia Chatbot\n",
        "def create_wiki_chatbot(topic):\n",
        "    print(f\"Getting Wikipedia information about: {topic}\")\n",
        "\n",
        "    # Get content from Wikipedia\n",
        "    wiki_content = get_wiki_content(topic)\n",
        "\n",
        "    # Process the text into chunks\n",
        "    text_chunks = process_text(wiki_content)\n",
        "    print(f\"Created {len(text_chunks)} text chunks\")\n",
        "\n",
        "    # Create vector database\n",
        "    vector_store = create_vector_db(text_chunks)\n",
        "    print(\"Created FAISS vector store\")\n",
        "\n",
        "    # Initialize the LLM\n",
        "    llm = get_llm()\n",
        "\n",
        "    # Set up conversation memory\n",
        "    memory = ConversationBufferMemory(\n",
        "        memory_key=\"chat_history\",\n",
        "        return_messages=True\n",
        "    )\n",
        "\n",
        "    # Create conversational chain\n",
        "    conversation_chain = ConversationalRetrievalChain.from_llm(\n",
        "        llm=llm,\n",
        "        retriever=vector_store.as_retriever(search_kwargs={\"k\": 3}),\n",
        "        memory=memory,\n",
        "        return_source_documents=True\n",
        "    )\n",
        "\n",
        "    return conversation_chain\n",
        "\n",
        "# STEP 8: Chat Function\n",
        "def chat_with_wiki(conversation_chain, query):\n",
        "    response = conversation_chain({\"question\": query})\n",
        "    return response[\"answer\"]\n",
        "\n",
        "# STEP 9: Main Chat Loop\n",
        "def run_wiki_chatbot(initial_topic=\"Artificial Intelligence\"):\n",
        "    # Create the chatbot with an initial topic\n",
        "    conversation_chain = create_wiki_chatbot(initial_topic)\n",
        "\n",
        "    print(\"\\n===== Wikipedia Chatbot is ready! =====\")\n",
        "    print(\"Type 'new topic: [your topic]' to change topics\")\n",
        "    print(\"Type 'exit' to quit\\n\")\n",
        "\n",
        "    while True:\n",
        "        user_input = input(\"You: \")\n",
        "\n",
        "        if user_input.lower() == 'exit':\n",
        "            print(\"Goodbye!\")\n",
        "            break\n",
        "\n",
        "        # Check if user wants to change the topic\n",
        "        if user_input.lower().startswith(\"new topic:\"):\n",
        "            new_topic = user_input[len(\"new topic:\"):].strip()\n",
        "            print(f\"\\nChanging topic to: {new_topic}\")\n",
        "            conversation_chain = create_wiki_chatbot(new_topic)\n",
        "            print(\"Topic changed. Ask a question about the new topic.\\n\")\n",
        "            continue\n",
        "\n",
        "        try:\n",
        "            # Get response from the chatbot\n",
        "            answer = chat_with_wiki(conversation_chain, user_input)\n",
        "            print(f\"\\nWikipediaBot: {answer}\\n\")\n",
        "        except Exception as e:\n",
        "            print(f\"Error: {str(e)}\")\n",
        "\n",
        "# STEP 10: Run the chatbot\n",
        "if __name__ == \"__main__\":\n",
        "    run_wiki_chatbot(\"Quantum Computing\")  # Start with this initial topic"
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "metadata": {
        "colab": {
          "background_save": true,
          "base_uri": "https://localhost:8080/"
        },
        "id": "OGCrjCvG0kF0",
        "outputId": "0a5b526f-13e9-469c-bc4e-15cddd6fde54"
      },
      "outputs": [
        {
          "name": "stdout",
          "output_type": "stream",
          "text": [
            "Getting Wikipedia information about: Quantum Computing\n",
            "Created 7 text chunks\n",
            "Created FAISS vector store\n",
            "\n",
            "===== Wikipedia Chatbot is ready! =====\n",
            "Type 'new topic: [your topic]' to change topics\n",
            "Type 'exit' to quit\n",
            "\n",
            "\n",
            "Changing topic to: MS Dhoni\n",
            "Getting Wikipedia information about: MS Dhoni\n",
            "Created 6 text chunks\n",
            "Created FAISS vector store\n",
            "Topic changed. Ask a question about the new topic.\n",
            "\n",
            "\n",
            "WikipediaBot: MS Dhoni's date of birth is July 7, 1981.\n",
            "\n",
            "\n",
            "Changing topic to: colours\n",
            "Getting Wikipedia information about: colours\n",
            "Created 5 text chunks\n",
            "Created FAISS vector store\n",
            "Topic changed. Ask a question about the new topic.\n",
            "\n",
            "\n",
            "WikipediaBot: Traditionally, the primary colors are red, yellow, and blue.\n",
            "\n"
          ]
        }
      ],
      "source": [
        "# STEP 1: Install Required Packages\n",
        "!pip install -q langchain langchain-community langchain-google-genai google-generativeai faiss-cpu wikipedia sentence-transformers\n",
        "\n",
        "# STEP 2: Import Libraries\n",
        "import os\n",
        "import google.generativeai as genai\n",
        "from langchain_google_genai import ChatGoogleGenerativeAI\n",
        "from langchain_community.vectorstores import FAISS\n",
        "from langchain_community.embeddings import HuggingFaceEmbeddings\n",
        "from langchain_community.utilities import WikipediaAPIWrapper\n",
        "from langchain.text_splitter import RecursiveCharacterTextSplitter\n",
        "from langchain.chains import ConversationalRetrievalChain\n",
        "from langchain.memory import ConversationBufferMemory\n",
        "from langchain.schema import SystemMessage, HumanMessage\n",
        "\n",
        "# STEP 3: Set your Google API Key (replace with your actual key)\n",
        "GOOGLE_API_KEY = \"AIzaSyCW5HzSyVUTqh7VbS6nFUiJsoo2fKSjbwM\"  # Replace with your actual API key\n",
        "os.environ[\"GOOGLE_API_KEY\"] = GOOGLE_API_KEY\n",
        "genai.configure(api_key=GOOGLE_API_KEY)\n",
        "\n",
        "# STEP 4: Initialize Gemini LLM\n",
        "def get_llm():\n",
        "    return ChatGoogleGenerativeAI(\n",
        "        model=\"gemini-1.5-pro\",\n",
        "        temperature=0.2,\n",
        "    )\n",
        "\n",
        "# STEP 5: Set up Wikipedia Content Retrieval and Processing\n",
        "def get_wiki_content(query, max_results=3):\n",
        "    # Use the WikipediaAPIWrapper to get content\n",
        "    wiki = WikipediaAPIWrapper(top_k_results=max_results)\n",
        "    wiki_content = wiki.run(query)\n",
        "    return wiki_content\n",
        "\n",
        "def process_text(text):\n",
        "    # Split the text into chunks for better processing\n",
        "    text_splitter = RecursiveCharacterTextSplitter(\n",
        "        chunk_size=1000,\n",
        "        chunk_overlap=200,\n",
        "        length_function=len\n",
        "    )\n",
        "    chunks = text_splitter.split_text(text)\n",
        "    return chunks\n",
        "\n",
        "# STEP 6: Create FAISS Vector Database\n",
        "def create_vector_db(text_chunks):\n",
        "    # Use Sentence Transformers for embeddings\n",
        "    embeddings = HuggingFaceEmbeddings(\n",
        "        model_name=\"all-MiniLM-L6-v2\",\n",
        "        model_kwargs={'device': 'cpu'}\n",
        "    )\n",
        "\n",
        "    # Create FAISS vector store from text chunks\n",
        "    vector_store = FAISS.from_texts(texts=text_chunks, embedding=embeddings)\n",
        "    return vector_store\n",
        "\n",
        "# STEP 7: Create the Wikipedia Chatbot\n",
        "def create_wiki_chatbot(topic):\n",
        "    print(f\"Getting Wikipedia information about: {topic}\")\n",
        "\n",
        "    # Get content from Wikipedia\n",
        "    wiki_content = get_wiki_content(topic)\n",
        "\n",
        "    # Process the text into chunks\n",
        "    text_chunks = process_text(wiki_content)\n",
        "    print(f\"Created {len(text_chunks)} text chunks\")\n",
        "\n",
        "    # Create vector database\n",
        "    vector_store = create_vector_db(text_chunks)\n",
        "    print(\"Created FAISS vector store\")\n",
        "\n",
        "    # Initialize the LLM\n",
        "    llm = get_llm()\n",
        "\n",
        "    # Set up conversation memory with explicit output key\n",
        "    memory = ConversationBufferMemory(\n",
        "        memory_key=\"chat_history\",\n",
        "        return_messages=True,\n",
        "        output_key=\"answer\"  # Explicitly specify the output key\n",
        "    )\n",
        "\n",
        "    # Create conversational chain\n",
        "    conversation_chain = ConversationalRetrievalChain.from_llm(\n",
        "        llm=llm,\n",
        "        retriever=vector_store.as_retriever(search_kwargs={\"k\": 3}),\n",
        "        memory=memory,\n",
        "        return_source_documents=True\n",
        "    )\n",
        "\n",
        "    return conversation_chain\n",
        "\n",
        "# STEP 8: Chat Function\n",
        "def chat_with_wiki(conversation_chain, query):\n",
        "    response = conversation_chain({\"question\": query})\n",
        "    return response[\"answer\"]\n",
        "\n",
        "# STEP 9: Main Chat Loop\n",
        "def run_wiki_chatbot(initial_topic=\"MS Dhoni\"):\n",
        "    # Create the chatbot with an initial topic\n",
        "    conversation_chain = create_wiki_chatbot(initial_topic)\n",
        "\n",
        "    print(\"\\n===== Wikipedia Chatbot is ready! =====\")\n",
        "    print(\"Type 'new topic: [your topic]' to change topics\")\n",
        "    print(\"Type 'exit' to quit\\n\")\n",
        "\n",
        "    while True:\n",
        "        user_input = input(\"You: \")\n",
        "\n",
        "        if user_input.lower() == 'exit':\n",
        "            print(\"Goodbye!\")\n",
        "            break\n",
        "\n",
        "        # Check if user wants to change the topic\n",
        "        if user_input.lower().startswith(\"new topic:\"):\n",
        "            new_topic = user_input[len(\"new topic:\"):].strip()\n",
        "            print(f\"\\nChanging topic to: {new_topic}\")\n",
        "            conversation_chain = create_wiki_chatbot(new_topic)\n",
        "            print(\"Topic changed. Ask a question about the new topic.\\n\")\n",
        "            continue\n",
        "\n",
        "        try:\n",
        "            # Get response from the chatbot\n",
        "            answer = chat_with_wiki(conversation_chain, user_input)\n",
        "            print(f\"\\nWikipediaBot: {answer}\\n\")\n",
        "        except Exception as e:\n",
        "            print(f\"Error: {str(e)}\")\n",
        "\n",
        "# STEP 10: Run the chatbot\n",
        "if __name__ == \"__main__\":\n",
        "    run_wiki_chatbot(\"Quantum Computing\")  # Start with this initial topic"
      ]
    }
  ],
  "metadata": {
    "colab": {
      "provenance": [],
      "authorship_tag": "ABX9TyN2ozQKkQ+xb2aBkQ0GNV0a",
      "include_colab_link": true
    },
    "kernelspec": {
      "display_name": "Python 3",
      "name": "python3"
    },
    "language_info": {
      "name": "python"
    },
    "widgets": {
      "application/vnd.jupyter.widget-state+json": {
        "02359595fc4947d3adfb6bd1a5c22172": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "DescriptionStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "DescriptionStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "description_width": ""
          }
        },
        "03a49ad655ca47bf9ca370a015b39246": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "0a638b778fe143a68f203b4db5d96d62": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "0b0bed92af8a4b6ca58ad836947912d8": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "0bd966507e234304a766730adda79c92": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "0d7980c7cd7e4ceba45c33bdbfc524e3": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HTMLModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HTMLModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HTMLView",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_75a631a3ad094bfd864179ba6c43aecb",
            "placeholder": "​",
            "style": "IPY_MODEL_9c6dc2c9475748f48ff43308b550adff",
            "value": " 10.5k/10.5k [00:00&lt;00:00, 836kB/s]"
          }
        },
        "10b8f12856794c69a07b1c4603ba4dd1": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HTMLModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HTMLModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HTMLView",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_36412ed310534e83baf771f95b3eb6d7",
            "placeholder": "​",
            "style": "IPY_MODEL_3045354454cd46cd881579313730b0a6",
            "value": "tokenizer_config.json: 100%"
          }
        },
        "11ffad173875498490c4275f067ae339": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HTMLModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HTMLModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HTMLView",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_1419789f9775401d81d640367cbed4d5",
            "placeholder": "​",
            "style": "IPY_MODEL_ce35ea71bd7446308644f5aedfe5fea4",
            "value": " 232k/232k [00:00&lt;00:00, 4.24MB/s]"
          }
        },
        "1419789f9775401d81d640367cbed4d5": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "1430ecb388a24db3a0c41060a67643cc": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "DescriptionStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "DescriptionStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "description_width": ""
          }
        },
        "1682424cce2e495cbbad35409c3fcac1": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "DescriptionStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "DescriptionStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "description_width": ""
          }
        },
        "178ae49394a34ce4a4d5ca83bbd8d202": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HTMLModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HTMLModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HTMLView",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_0a638b778fe143a68f203b4db5d96d62",
            "placeholder": "​",
            "style": "IPY_MODEL_8bbd731e3b5749ff946d52e915413fe6",
            "value": "modules.json: 100%"
          }
        },
        "198c7b289a7241bc813c5f3ade5ac1eb": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "1eda352518b5449b97b50212e9d65d2c": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HBoxModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HBoxModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HBoxView",
            "box_style": "",
            "children": [
              "IPY_MODEL_b2f39f1bc02b4c4c8631d99fa2019bae",
              "IPY_MODEL_c903f49bd9e144dfb5704215cc11bb4d",
              "IPY_MODEL_2a389830aa2647d0a0d761b19376da63"
            ],
            "layout": "IPY_MODEL_9a5d4b973389432186c8f99d6678abbe"
          }
        },
        "1fb2f4e41fa241cb901c6fb0a4910408": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "2115ce2ded7443c3918ae415cf09d2d7": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "236bf4b5c8ee46cf8014e5d525742a63": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "FloatProgressModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "FloatProgressModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "ProgressView",
            "bar_style": "success",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_1fb2f4e41fa241cb901c6fb0a4910408",
            "max": 612,
            "min": 0,
            "orientation": "horizontal",
            "style": "IPY_MODEL_41b15b3f69e24652bc7ddb144115715f",
            "value": 612
          }
        },
        "24d211a7bc7742a9a985333cc33f1086": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HBoxModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HBoxModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HBoxView",
            "box_style": "",
            "children": [
              "IPY_MODEL_85a1df7529334898977595faf103aa21",
              "IPY_MODEL_297979735fd84929aee6c569951e6e57",
              "IPY_MODEL_afed89d2221841119c06d392aafca362"
            ],
            "layout": "IPY_MODEL_6d4d0f1a8c734d489f1b273bdc9a3fd2"
          }
        },
        "2592edb6fbc84b64ac2311ffb0f3fd71": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "DescriptionStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "DescriptionStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "description_width": ""
          }
        },
        "26cd5e106e2844c494f79d302b32f1bd": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "FloatProgressModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "FloatProgressModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "ProgressView",
            "bar_style": "success",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_45e6971ed75c4aea90886beb7d05248d",
            "max": 231508,
            "min": 0,
            "orientation": "horizontal",
            "style": "IPY_MODEL_29218c71ccb14626b506321ed67afb30",
            "value": 231508
          }
        },
        "2825de0b28b14f5a89d14983ad39b040": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "ProgressStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "ProgressStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "bar_color": null,
            "description_width": ""
          }
        },
        "29218c71ccb14626b506321ed67afb30": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "ProgressStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "ProgressStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "bar_color": null,
            "description_width": ""
          }
        },
        "297979735fd84929aee6c569951e6e57": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "FloatProgressModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "FloatProgressModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "ProgressView",
            "bar_style": "success",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_6c369920b4674439aa5884e06cfc1d05",
            "max": 190,
            "min": 0,
            "orientation": "horizontal",
            "style": "IPY_MODEL_9d5da1c6c00044ee88fdc0ca5af1d260",
            "value": 190
          }
        },
        "2a389830aa2647d0a0d761b19376da63": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HTMLModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HTMLModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HTMLView",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_9fb6952ef5a34364a6cab61021aff7b0",
            "placeholder": "​",
            "style": "IPY_MODEL_cc5087fd30e3440c85e49973ac2e85f2",
            "value": " 53.0/53.0 [00:00&lt;00:00, 4.32kB/s]"
          }
        },
        "2b48a439b6b84cc19381f04b2184c935": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "ProgressStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "ProgressStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "bar_color": null,
            "description_width": ""
          }
        },
        "2d69e16ad85b4e198e1772691a64f42f": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HTMLModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HTMLModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HTMLView",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_5be0829c71dc441c96284f2d41e8233b",
            "placeholder": "​",
            "style": "IPY_MODEL_2592edb6fbc84b64ac2311ffb0f3fd71",
            "value": "config.json: 100%"
          }
        },
        "2e2fd56fc4cd438ab596787a91e6a753": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "3045354454cd46cd881579313730b0a6": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "DescriptionStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "DescriptionStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "description_width": ""
          }
        },
        "326b46cb624647eaa22c94abd56b38d9": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HTMLModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HTMLModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HTMLView",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_af503ca763254a55b6515fc1e4f45f42",
            "placeholder": "​",
            "style": "IPY_MODEL_4936189f15954cf687a10afc7b471c83",
            "value": " 612/612 [00:00&lt;00:00, 55.7kB/s]"
          }
        },
        "36412ed310534e83baf771f95b3eb6d7": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "398b746ac40c435ba7ed29323558cd9c": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "3abc55d93e334c5493b3370dbbe8c61a": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HBoxModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HBoxModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HBoxView",
            "box_style": "",
            "children": [
              "IPY_MODEL_8e35498030ff4c8ebd3a9693066571c1",
              "IPY_MODEL_5e91b8638d9d466aa97097751e8a7ba4",
              "IPY_MODEL_7424b178e5b34aa9ba2c83c5d32d7db0"
            ],
            "layout": "IPY_MODEL_0bd966507e234304a766730adda79c92"
          }
        },
        "3e03b92fe59b4c83b01ddb12e9ad90e1": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HBoxModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HBoxModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HBoxView",
            "box_style": "",
            "children": [
              "IPY_MODEL_8a36a3ba377a40d3a15a643154d69b54",
              "IPY_MODEL_26cd5e106e2844c494f79d302b32f1bd",
              "IPY_MODEL_11ffad173875498490c4275f067ae339"
            ],
            "layout": "IPY_MODEL_eba8c3e8a8794d22a4a40ee489a320a4"
          }
        },
        "400719cb832e4932ab52bf5e470738a5": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HBoxModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HBoxModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HBoxView",
            "box_style": "",
            "children": [
              "IPY_MODEL_83244d4ed46d4367b0d0a652da8e71b3",
              "IPY_MODEL_9961baf94e844e58b6cb587b3bb93221",
              "IPY_MODEL_c4d40455bcef430db00e8acf2aa7b93b"
            ],
            "layout": "IPY_MODEL_4e82dd3ceadf43d18d4257d12ebdaa83"
          }
        },
        "41b15b3f69e24652bc7ddb144115715f": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "ProgressStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "ProgressStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "bar_color": null,
            "description_width": ""
          }
        },
        "4473ee3c69da48b6958a5a218ab07b7e": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "45e6971ed75c4aea90886beb7d05248d": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "477c348d35c345dbbe633f7d7ee3f6df": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HTMLModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HTMLModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HTMLView",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_7cf17f9a4f6a46e5b38541f7bf7306bc",
            "placeholder": "​",
            "style": "IPY_MODEL_1430ecb388a24db3a0c41060a67643cc",
            "value": " 466k/466k [00:00&lt;00:00, 10.8MB/s]"
          }
        },
        "4900f81bf89d4ff2a84c42bda673062c": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "FloatProgressModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "FloatProgressModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "ProgressView",
            "bar_style": "success",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_c3ff6c25b38740559eaaacb693b95432",
            "max": 350,
            "min": 0,
            "orientation": "horizontal",
            "style": "IPY_MODEL_9330cdfbbbf149e1a4d11edf052cd983",
            "value": 350
          }
        },
        "4936189f15954cf687a10afc7b471c83": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "DescriptionStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "DescriptionStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "description_width": ""
          }
        },
        "4ba22a69a87f49e7bddd3cb5498ab4c6": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HTMLModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HTMLModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HTMLView",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_8b55c987ae7b4635adcdef3a006cf06e",
            "placeholder": "​",
            "style": "IPY_MODEL_02359595fc4947d3adfb6bd1a5c22172",
            "value": " 350/350 [00:00&lt;00:00, 26.9kB/s]"
          }
        },
        "4cd5eb592095405ca7699f856851b4b0": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "4e3c317e3da5466a9097343018f16f26": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "4e82dd3ceadf43d18d4257d12ebdaa83": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "4efb2f3c80ad4fcdb11cd2dc0db22d5e": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "DescriptionStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "DescriptionStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "description_width": ""
          }
        },
        "515efe88993c421685cbea34fe223cc6": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "DescriptionStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "DescriptionStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "description_width": ""
          }
        },
        "54cacaaef94d41dcbd8508cd3c341c92": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HTMLModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HTMLModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HTMLView",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_398b746ac40c435ba7ed29323558cd9c",
            "placeholder": "​",
            "style": "IPY_MODEL_d7e396e439cf438f9fbeac7eaa9e37c0",
            "value": " 90.9M/90.9M [00:00&lt;00:00, 144MB/s]"
          }
        },
        "5be0829c71dc441c96284f2d41e8233b": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "5c505d88f5bd4568aaf7386ec4c3c271": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HBoxModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HBoxModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HBoxView",
            "box_style": "",
            "children": [
              "IPY_MODEL_6bbf029a90c14d53925cde8a33f0dde5",
              "IPY_MODEL_bbe04bab27bf4bb8b8ba9b24b4301c34",
              "IPY_MODEL_54cacaaef94d41dcbd8508cd3c341c92"
            ],
            "layout": "IPY_MODEL_8b4d9831c6ac43c5a02677cfd741f927"
          }
        },
        "5e91b8638d9d466aa97097751e8a7ba4": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "FloatProgressModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "FloatProgressModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "ProgressView",
            "bar_style": "success",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_aa56f547c0084046be6fc1e8cd4601c0",
            "max": 116,
            "min": 0,
            "orientation": "horizontal",
            "style": "IPY_MODEL_2825de0b28b14f5a89d14983ad39b040",
            "value": 116
          }
        },
        "66f9cbbc9b014e8a883f34174d5e6bb2": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "ProgressStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "ProgressStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "bar_color": null,
            "description_width": ""
          }
        },
        "683a808475e040b684d68c887faf07ae": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "68f42d2d023b40f29c70e3e4adc17a98": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HBoxModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HBoxModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HBoxView",
            "box_style": "",
            "children": [
              "IPY_MODEL_10b8f12856794c69a07b1c4603ba4dd1",
              "IPY_MODEL_4900f81bf89d4ff2a84c42bda673062c",
              "IPY_MODEL_4ba22a69a87f49e7bddd3cb5498ab4c6"
            ],
            "layout": "IPY_MODEL_03a49ad655ca47bf9ca370a015b39246"
          }
        },
        "6aaa2712dd024a2cad13590831134a96": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HBoxModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HBoxModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HBoxView",
            "box_style": "",
            "children": [
              "IPY_MODEL_178ae49394a34ce4a4d5ca83bbd8d202",
              "IPY_MODEL_b5c2345a00704ae1bf36515aefbb23e4",
              "IPY_MODEL_eda17cfb045f4e7dad91508d3719705b"
            ],
            "layout": "IPY_MODEL_7a332637135341b4adb6fa72d22f1aa4"
          }
        },
        "6bbf029a90c14d53925cde8a33f0dde5": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HTMLModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HTMLModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HTMLView",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_927515a2248943a9a07c498b7e1644ba",
            "placeholder": "​",
            "style": "IPY_MODEL_6c749b4de378485898690a5fe80b9cc2",
            "value": "model.safetensors: 100%"
          }
        },
        "6c369920b4674439aa5884e06cfc1d05": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "6c749b4de378485898690a5fe80b9cc2": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "DescriptionStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "DescriptionStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "description_width": ""
          }
        },
        "6d4d0f1a8c734d489f1b273bdc9a3fd2": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "6e7134ba60194823af6777d8bc32cc3a": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "7424b178e5b34aa9ba2c83c5d32d7db0": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HTMLModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HTMLModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HTMLView",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_bc9ee5cecdb34bb1bfe4789f5283765a",
            "placeholder": "​",
            "style": "IPY_MODEL_1682424cce2e495cbbad35409c3fcac1",
            "value": " 116/116 [00:00&lt;00:00, 8.76kB/s]"
          }
        },
        "75a631a3ad094bfd864179ba6c43aecb": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "75c46b3d009f4f3780488a23b6b2361a": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "7a332637135341b4adb6fa72d22f1aa4": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "7c001196edf044faa9dcd88328f8dcca": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "DescriptionStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "DescriptionStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "description_width": ""
          }
        },
        "7cf17f9a4f6a46e5b38541f7bf7306bc": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "83244d4ed46d4367b0d0a652da8e71b3": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HTMLModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HTMLModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HTMLView",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_683a808475e040b684d68c887faf07ae",
            "placeholder": "​",
            "style": "IPY_MODEL_7c001196edf044faa9dcd88328f8dcca",
            "value": "special_tokens_map.json: 100%"
          }
        },
        "85a1df7529334898977595faf103aa21": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HTMLModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HTMLModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HTMLView",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_a17c5907f34a4830aeab94e7da23516a",
            "placeholder": "​",
            "style": "IPY_MODEL_8da7cd7e50284e0bb8c2e4b5dc95f8e7",
            "value": "config.json: 100%"
          }
        },
        "8a36a3ba377a40d3a15a643154d69b54": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HTMLModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HTMLModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HTMLView",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_2115ce2ded7443c3918ae415cf09d2d7",
            "placeholder": "​",
            "style": "IPY_MODEL_e7264047e1d64432803c9e8d19b880f0",
            "value": "vocab.txt: 100%"
          }
        },
        "8b4d9831c6ac43c5a02677cfd741f927": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "8b50a41fa52c4a2091033320e445295f": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "DescriptionStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "DescriptionStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "description_width": ""
          }
        },
        "8b55c987ae7b4635adcdef3a006cf06e": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "8bbd731e3b5749ff946d52e915413fe6": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "DescriptionStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "DescriptionStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "description_width": ""
          }
        },
        "8c9e2d3e56a444eea3133835df1d8812": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "ProgressStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "ProgressStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "bar_color": null,
            "description_width": ""
          }
        },
        "8da7cd7e50284e0bb8c2e4b5dc95f8e7": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "DescriptionStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "DescriptionStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "description_width": ""
          }
        },
        "8e35498030ff4c8ebd3a9693066571c1": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HTMLModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HTMLModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HTMLView",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_b30224161bd84ba98bf75614a6bf0900",
            "placeholder": "​",
            "style": "IPY_MODEL_515efe88993c421685cbea34fe223cc6",
            "value": "config_sentence_transformers.json: 100%"
          }
        },
        "927515a2248943a9a07c498b7e1644ba": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "9330cdfbbbf149e1a4d11edf052cd983": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "ProgressStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "ProgressStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "bar_color": null,
            "description_width": ""
          }
        },
        "972e8c96802f4259bf9f460d804914f0": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "9961baf94e844e58b6cb587b3bb93221": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "FloatProgressModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "FloatProgressModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "ProgressView",
            "bar_style": "success",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_c0eabd24567042dd8921da7fdcfe1fa8",
            "max": 112,
            "min": 0,
            "orientation": "horizontal",
            "style": "IPY_MODEL_8c9e2d3e56a444eea3133835df1d8812",
            "value": 112
          }
        },
        "9a5d4b973389432186c8f99d6678abbe": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "9c6dc2c9475748f48ff43308b550adff": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "DescriptionStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "DescriptionStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "description_width": ""
          }
        },
        "9cc83daeb1ad4ebca5fe8f08fb26e7b2": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "9d5da1c6c00044ee88fdc0ca5af1d260": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "ProgressStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "ProgressStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "bar_color": null,
            "description_width": ""
          }
        },
        "9fb6952ef5a34364a6cab61021aff7b0": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "a17c5907f34a4830aeab94e7da23516a": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "a37136f00023409cbd5c2a575af2460b": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "ProgressStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "ProgressStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "bar_color": null,
            "description_width": ""
          }
        },
        "aa56f547c0084046be6fc1e8cd4601c0": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "ae977b29022c40b4bb2fdeb5bc111b1c": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "af503ca763254a55b6515fc1e4f45f42": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "afed89d2221841119c06d392aafca362": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HTMLModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HTMLModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HTMLView",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_ff9575d0cffb4cf9bcf725cb26a55a1e",
            "placeholder": "​",
            "style": "IPY_MODEL_e990abcf62c44b17ad3c7122fe2c0cc5",
            "value": " 190/190 [00:00&lt;00:00, 12.2kB/s]"
          }
        },
        "b2f39f1bc02b4c4c8631d99fa2019bae": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HTMLModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HTMLModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HTMLView",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_9cc83daeb1ad4ebca5fe8f08fb26e7b2",
            "placeholder": "​",
            "style": "IPY_MODEL_c8f65254038d497cb00b998ed7066dac",
            "value": "sentence_bert_config.json: 100%"
          }
        },
        "b30224161bd84ba98bf75614a6bf0900": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "b5c2345a00704ae1bf36515aefbb23e4": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "FloatProgressModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "FloatProgressModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "ProgressView",
            "bar_style": "success",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_75c46b3d009f4f3780488a23b6b2361a",
            "max": 349,
            "min": 0,
            "orientation": "horizontal",
            "style": "IPY_MODEL_f6e22ce791794c82950afac6768294ed",
            "value": 349
          }
        },
        "ba063bf8e4fb4874923c3050d5eff5d1": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HBoxModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HBoxModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HBoxView",
            "box_style": "",
            "children": [
              "IPY_MODEL_2d69e16ad85b4e198e1772691a64f42f",
              "IPY_MODEL_236bf4b5c8ee46cf8014e5d525742a63",
              "IPY_MODEL_326b46cb624647eaa22c94abd56b38d9"
            ],
            "layout": "IPY_MODEL_fa56ea8e04ce43bdb971909135be3696"
          }
        },
        "bbe04bab27bf4bb8b8ba9b24b4301c34": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "FloatProgressModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "FloatProgressModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "ProgressView",
            "bar_style": "success",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_2e2fd56fc4cd438ab596787a91e6a753",
            "max": 90868376,
            "min": 0,
            "orientation": "horizontal",
            "style": "IPY_MODEL_2b48a439b6b84cc19381f04b2184c935",
            "value": 90868376
          }
        },
        "bc69ee7f189f48b3bc1fab9f2effc0fd": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "FloatProgressModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "FloatProgressModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "ProgressView",
            "bar_style": "success",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_198c7b289a7241bc813c5f3ade5ac1eb",
            "max": 466247,
            "min": 0,
            "orientation": "horizontal",
            "style": "IPY_MODEL_f81a912e5f4b42798777a7016af8da68",
            "value": 466247
          }
        },
        "bc9ee5cecdb34bb1bfe4789f5283765a": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "c0eabd24567042dd8921da7fdcfe1fa8": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "c3ff6c25b38740559eaaacb693b95432": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "c4d40455bcef430db00e8acf2aa7b93b": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HTMLModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HTMLModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HTMLView",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_0b0bed92af8a4b6ca58ad836947912d8",
            "placeholder": "​",
            "style": "IPY_MODEL_8b50a41fa52c4a2091033320e445295f",
            "value": " 112/112 [00:00&lt;00:00, 6.74kB/s]"
          }
        },
        "c8f65254038d497cb00b998ed7066dac": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "DescriptionStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "DescriptionStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "description_width": ""
          }
        },
        "c903f49bd9e144dfb5704215cc11bb4d": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "FloatProgressModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "FloatProgressModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "ProgressView",
            "bar_style": "success",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_4e3c317e3da5466a9097343018f16f26",
            "max": 53,
            "min": 0,
            "orientation": "horizontal",
            "style": "IPY_MODEL_a37136f00023409cbd5c2a575af2460b",
            "value": 53
          }
        },
        "cbedc2e4f79d47669ac0837949dc621f": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "DescriptionStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "DescriptionStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "description_width": ""
          }
        },
        "cbfce47239744e8b8acb6a350825aabc": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "DescriptionStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "DescriptionStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "description_width": ""
          }
        },
        "cc5087fd30e3440c85e49973ac2e85f2": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "DescriptionStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "DescriptionStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "description_width": ""
          }
        },
        "ce35ea71bd7446308644f5aedfe5fea4": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "DescriptionStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "DescriptionStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "description_width": ""
          }
        },
        "d4cdfe1c32d84384a9af477ebc1487d4": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HBoxModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HBoxModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HBoxView",
            "box_style": "",
            "children": [
              "IPY_MODEL_e2aa91ddd61643679e81f5ffaaaac496",
              "IPY_MODEL_bc69ee7f189f48b3bc1fab9f2effc0fd",
              "IPY_MODEL_477c348d35c345dbbe633f7d7ee3f6df"
            ],
            "layout": "IPY_MODEL_6e7134ba60194823af6777d8bc32cc3a"
          }
        },
        "d7e396e439cf438f9fbeac7eaa9e37c0": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "DescriptionStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "DescriptionStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "description_width": ""
          }
        },
        "e165e11668ed45deaacf4d221e0b77c7": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "FloatProgressModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "FloatProgressModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "ProgressView",
            "bar_style": "success",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_ae977b29022c40b4bb2fdeb5bc111b1c",
            "max": 10454,
            "min": 0,
            "orientation": "horizontal",
            "style": "IPY_MODEL_66f9cbbc9b014e8a883f34174d5e6bb2",
            "value": 10454
          }
        },
        "e2aa91ddd61643679e81f5ffaaaac496": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HTMLModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HTMLModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HTMLView",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_972e8c96802f4259bf9f460d804914f0",
            "placeholder": "​",
            "style": "IPY_MODEL_cbfce47239744e8b8acb6a350825aabc",
            "value": "tokenizer.json: 100%"
          }
        },
        "e7264047e1d64432803c9e8d19b880f0": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "DescriptionStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "DescriptionStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "description_width": ""
          }
        },
        "e9303a5d5aa34009bb23037ba3398c5c": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HTMLModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HTMLModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HTMLView",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_ebb6c3fa5b7f4335993729fb568d193e",
            "placeholder": "​",
            "style": "IPY_MODEL_4efb2f3c80ad4fcdb11cd2dc0db22d5e",
            "value": "README.md: 100%"
          }
        },
        "e990abcf62c44b17ad3c7122fe2c0cc5": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "DescriptionStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "DescriptionStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "description_width": ""
          }
        },
        "eba8c3e8a8794d22a4a40ee489a320a4": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "ebb6c3fa5b7f4335993729fb568d193e": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "eda17cfb045f4e7dad91508d3719705b": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HTMLModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HTMLModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HTMLView",
            "description": "",
            "description_tooltip": null,
            "layout": "IPY_MODEL_4cd5eb592095405ca7699f856851b4b0",
            "placeholder": "​",
            "style": "IPY_MODEL_cbedc2e4f79d47669ac0837949dc621f",
            "value": " 349/349 [00:00&lt;00:00, 28.9kB/s]"
          }
        },
        "f5a584e3002d47e19d80e9a317fd4799": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "HBoxModel",
          "state": {
            "_dom_classes": [],
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "HBoxModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/controls",
            "_view_module_version": "1.5.0",
            "_view_name": "HBoxView",
            "box_style": "",
            "children": [
              "IPY_MODEL_e9303a5d5aa34009bb23037ba3398c5c",
              "IPY_MODEL_e165e11668ed45deaacf4d221e0b77c7",
              "IPY_MODEL_0d7980c7cd7e4ceba45c33bdbfc524e3"
            ],
            "layout": "IPY_MODEL_4473ee3c69da48b6958a5a218ab07b7e"
          }
        },
        "f6e22ce791794c82950afac6768294ed": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "ProgressStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "ProgressStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "bar_color": null,
            "description_width": ""
          }
        },
        "f81a912e5f4b42798777a7016af8da68": {
          "model_module": "@jupyter-widgets/controls",
          "model_module_version": "1.5.0",
          "model_name": "ProgressStyleModel",
          "state": {
            "_model_module": "@jupyter-widgets/controls",
            "_model_module_version": "1.5.0",
            "_model_name": "ProgressStyleModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "StyleView",
            "bar_color": null,
            "description_width": ""
          }
        },
        "fa56ea8e04ce43bdb971909135be3696": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        },
        "ff9575d0cffb4cf9bcf725cb26a55a1e": {
          "model_module": "@jupyter-widgets/base",
          "model_module_version": "1.2.0",
          "model_name": "LayoutModel",
          "state": {
            "_model_module": "@jupyter-widgets/base",
            "_model_module_version": "1.2.0",
            "_model_name": "LayoutModel",
            "_view_count": null,
            "_view_module": "@jupyter-widgets/base",
            "_view_module_version": "1.2.0",
            "_view_name": "LayoutView",
            "align_content": null,
            "align_items": null,
            "align_self": null,
            "border": null,
            "bottom": null,
            "display": null,
            "flex": null,
            "flex_flow": null,
            "grid_area": null,
            "grid_auto_columns": null,
            "grid_auto_flow": null,
            "grid_auto_rows": null,
            "grid_column": null,
            "grid_gap": null,
            "grid_row": null,
            "grid_template_areas": null,
            "grid_template_columns": null,
            "grid_template_rows": null,
            "height": null,
            "justify_content": null,
            "justify_items": null,
            "left": null,
            "margin": null,
            "max_height": null,
            "max_width": null,
            "min_height": null,
            "min_width": null,
            "object_fit": null,
            "object_position": null,
            "order": null,
            "overflow": null,
            "overflow_x": null,
            "overflow_y": null,
            "padding": null,
            "right": null,
            "top": null,
            "visibility": null,
            "width": null
          }
        }
      }
    }
  },
  "nbformat": 4,
  "nbformat_minor": 0
}
